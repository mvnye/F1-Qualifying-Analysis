# %%
import pandas as pd
import numpy as np
import panel as pn
import holoviews as hv
pn.extension('tabulator', 'plotly')


import plotly.graph_objects as go
import pandas as pd
from plotly.subplots import make_subplots

import pandas as pd
import numpy as np
from typing import List, Dict
import logging
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='f695aa92-ce25-4209-8701-81248c211b66'>
#   <div id="d599271e-ee07-4e9a-9519-688b252a165d" data-root-id="f695aa92-ce25-4209-8701-81248c211b66" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"5b1446f3-83ea-4484-aad7-d7874a6fdf58":{"version":"3.6.0","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"f695aa92-ce25-4209-8701-81248c211b66"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"76ba1303-1b76-4d40-94b4-c785a23d3135","attributes":{"plot_id":"f695aa92-ce25-4209-8701-81248c211b66","comm_id":"9a8a6057aaee44789112e1346f5407af","client_comm_id":"0b0cb390069e4ed98b829092ada5e852"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","def ...
#   var render_items = [{"docid":"5b1446f3-83ea-4484-aad7-d7874a6fdf58","roots":{"f695aa92-ce25-4209-8701-81248c211b66":"d599271e-ee07-4e9a-9519-688b252a165d"},"root_ids":["f695aa92-ce25-4209-8701-81248c211b66"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined && ( root.Tabulator !== undefined) && ( root.Plotly !== undefined) && ( root.Tabulator !== undefined) && ( root.Plotly !== undefined))
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %% [markdown]
# ### Data Processing for Career Timeline

# %%
quali_data = pd.read_csv('data/quali_data_2018_to_2021.csv')
quali_data.head()
# Out:
#       Driver  DriverNumber                 LapTime  LapNumber  Stint  \
# 0  B HARTLEY            28  0 days 00:01:38.713000        2.0    1.0
# 1  B HARTLEY            28  0 days 00:01:38.127000        5.0    2.0
# 2  B HARTLEY            28  0 days 00:01:37.994000        8.0    3.0
# 3  C LECLERC            16  0 days 00:01:38.968000        2.0    1.0
# 4  C LECLERC            16  0 days 00:02:22.825000        3.0    1.0
#
#               Sector1Time             Sector2Time             Sector3Time  \
# 0  0 days 00:00:17.567000  0 days 00:00:41.797000  0 days 00:00:39.349000
# 1  0 days 00:00:17.513000  0 days 00:00:41.709000  0 days 00:00:38.905000
# 2  0 days 00:00:17.450000  0 days 00:00:41.589000  0 days 00:00:38.955000
# 3  0 days 00:00:17.271000  0 days 00:00:41.969000  0 days 00:00:39.728000
# 4  0 days 00:00:29.037000  0 days 00:01:01.227000  0 days 00:00:52.561000
#
#        Sector1SessionTime      Sector2SessionTime  ...   Compound  TyreLife  \
# 0  0 days 00:17:55.973000  0 days 00:18:37.770000  ...  HYPERSOFT       2.0
# 1  0 days 00:25:30.706000  0 days 00:26:12.415000  ...  HYPERSOFT       2.0
# 2  0 days 00:33:01.972000  0 days 00:33:43.561000  ...  HYPERSOFT       2.0
# 3  0 days 00:17:34.899000  0 days 00:18:16.868000  ...  HYPERSOFT       2.0
# 4  0 days 00:19:25.633000  0 days 00:20:26.860000  ...  HYPERSOFT       3.0
#
#    FreshTyre        Team            LapStartTime  TrackStatus  \
# 0       True  Toro Rosso  0 days 00:17:38.406000          1.0
# 1       True  Toro Rosso  0 days 00:25:13.193000          1.0
# 2       True  Toro Rosso  0 days 00:32:44.522000          1.0
# 3       True      Sauber  0 days 00:17:17.628000          1.0
# 4       True      Sauber  0 days 00:18:56.596000          1.0
#
#   QualifyingPosition  Year             EventName WetSession
# 0               16.0  2018  Abu Dhabi Grand Prix      False
# 1               16.0  2018  Abu Dhabi Grand Prix      False
# 2               16.0  2018  Abu Dhabi Grand Prix      False
# 3                8.0  2018  Abu Dhabi Grand Prix      False
# 4                8.0  2018  Abu Dhabi Grand Prix      False
#
# [5 rows x 26 columns]

# %%
print(quali_data[['Sector1Time', 'Sector2Time', 'Sector3Time']].dtypes)
# Out:
# Sector1Time    object
# Sector2Time    object
# Sector3Time    object
# dtype: object

# %%
# Convert time columns from string to Timedelta
quali_data['LapTime'] = pd.to_timedelta(quali_data['LapTime'])
quali_data['Sector1Time'] = pd.to_timedelta(quali_data['Sector1Time'])
quali_data['Sector2Time'] = pd.to_timedelta(quali_data['Sector2Time'])
quali_data['Sector3Time'] = pd.to_timedelta(quali_data['Sector3Time'])
quali_data['Sector1SessionTime'] = pd.to_timedelta(quali_data['Sector1SessionTime'])
quali_data['Sector2SessionTime'] = pd.to_timedelta(quali_data['Sector2SessionTime'])
quali_data['Sector3SessionTime'] = pd.to_timedelta(quali_data['Sector3SessionTime'])
quali_data['LapStartTime'] = pd.to_timedelta(quali_data['LapStartTime'])

print(quali_data[['LapTime', 'Sector1Time', 'Sector2Time', 'Sector3Time', 'Sector1SessionTime', 
                  'Sector2SessionTime', 'Sector3SessionTime', 'LapStartTime']].dtypes)


# Now convert the Timedelta columns to total seconds
quali_data['LapTimeSeconds'] = quali_data['LapTime'].apply(lambda x: x.total_seconds())
quali_data['Sector1TimeSeconds'] = quali_data['Sector1Time'].apply(lambda x: x.total_seconds())
quali_data['Sector2TimeSeconds'] = quali_data['Sector2Time'].apply(lambda x: x.total_seconds())
quali_data['Sector3TimeSeconds'] = quali_data['Sector3Time'].apply(lambda x: x.total_seconds())

quali_data['Sector1SessionTimeSeconds'] = quali_data['Sector1SessionTime'].apply(lambda x: x.total_seconds())
quali_data['Sector2SessionTimeSeconds'] = quali_data['Sector2SessionTime'].apply(lambda x: x.total_seconds())
quali_data['Sector3SessionTimeSeconds'] = quali_data['Sector3SessionTime'].apply(lambda x: x.total_seconds())

# Lap Start Time should also be converted to seconds for consistency
quali_data['LapStartTimeSeconds'] = quali_data['LapStartTime'].apply(lambda x: x.total_seconds())
# Out:
# LapTime               timedelta64[ns]
# Sector1Time           timedelta64[ns]
# Sector2Time           timedelta64[ns]
# Sector3Time           timedelta64[ns]
# Sector1SessionTime    timedelta64[ns]
# Sector2SessionTime    timedelta64[ns]
# Sector3SessionTime    timedelta64[ns]
# LapStartTime          timedelta64[ns]
# dtype: object

# %% [markdown]
# ### Calculate Metrics for Career Timeline

# %%
import pandas as pd
import numpy as np
from typing import List, Dict
import logging

# Set up logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

def validate_pole_position(event_data: pd.DataFrame, event_name: str, year: int) -> pd.DataFrame:
    """
    Validate pole position data and identify any inconsistencies.
    Returns the verified pole position data.
    """
    # Get all drivers marked as pole position
    pole_entries = event_data[event_data['QualifyingPosition'] == 1]
    
    if pole_entries.empty:
        logger.error(f"No pole position entry found for {event_name} {year}")
        return None, None
    
    pole_driver = pole_entries['Driver'].iloc[0]
    pole_time = pole_entries['LapTimeSeconds'].min()
        
    if len(pole_entries['Driver'].unique()) > 1:
        logger.error(f"Multiple pole position entries found for {event_name} {year}:")
        for _, entry in pole_entries.iterrows():
            logger.error(f"Driver: {entry['Driver']}, Time: {entry['LapTimeSeconds']}")
    
    # Find the actual fastest lap
    fastest_lap = event_data.loc[event_data['LapTimeSeconds'].idxmin()]
    
    # Check if pole position entry matches fastest lap
    if fastest_lap['LapTimeSeconds'] < pole_time:
        logger.error(
            f"Inconsistency at {event_name} {year}:\n"
            f"Pole Position: {pole_driver} ({pole_time}s)\n"
            f"Fastest Lap: {fastest_lap['Driver']} ({fastest_lap['LapTimeSeconds']}s)\n"
            f"Difference: {pole_time - fastest_lap['LapTimeSeconds']}s"
        )
    
    return pole_driver, pole_time

def process_qualifying_data(quali_data: pd.DataFrame) -> List[Dict]:
    """
    Process F1 qualifying data with enhanced validation and debugging.
    
    Args:
        quali_data: DataFrame with columns including Driver, Team, QualifyingPosition,
                   LapTimeSeconds, Year, EventName, etc.
    
    Returns:
        List of dictionaries containing processed qualifying data per driver per year
    """
    timeline_data = []
    
    # Verify required columns
    required_columns = ['Year', 'EventName', 'Team', 'Driver', 'QualifyingPosition', 
                       'LapTimeSeconds', 'LapNumber', 'Stint', 'TrackStatus']
    missing_columns = [col for col in required_columns if col not in quali_data.columns]
    if missing_columns:
        raise ValueError(f"Missing required columns: {missing_columns}")
    
    for year in quali_data['Year'].unique():
        year_data = quali_data[quali_data['Year'] == year]
        
        for event_name, event_data in year_data.groupby('EventName'):
            #logger.info(f"Processing {event_name} {year}")
            
            # Get best lap time for each driver at this event
            driver_best_laps = event_data.groupby('Driver')['LapTimeSeconds'].min()
            #logger.info("\nBest lap times:")
            #for driver, time in driver_best_laps.items():
                #logger.info(f"{driver}: {time:.3f}s")
            
            # Validate pole position data
            pole_driver, pole_time = validate_pole_position(event_data, event_name, year)
            if pole_driver is None:
                continue
            
            team_groups = event_data.groupby('Team')
            
            for team, team_data in team_groups:
                drivers = team_data['Driver'].unique()
                
                # Initialize gaps dict
                gaps = {driver: np.nan for driver in drivers}
                
                # Calculate teammate gaps only if we have exactly 2 drivers
                if len(drivers) == 2:
                    driver_times = {
                        driver: team_data[team_data['Driver'] == driver]['LapTimeSeconds'].min()
                        for driver in drivers
                    }
                    driver1, driver2 = drivers
                    time1, time2 = driver_times[driver1], driver_times[driver2]
                    
                    if not (np.isnan(time1) or np.isnan(time2)):
                        gaps.update({
                            driver1: time1 - time2,
                            driver2: time2 - time1
                        })
                else:
                    pass
                    #logger.info(f'Incomplete teammate data: {len(drivers)} driver(s) for {team} at {event_name} {year}')
                
                # Process each driver
                for driver in drivers:
                    driver_data = team_data[team_data['Driver'] == driver]
                    best_lap_time = driver_data['LapTimeSeconds'].min()
                    qualifying_position = driver_data['QualifyingPosition'].iloc[0]
                    
                    # Calculate gap to pole
                    if qualifying_position == 1:
                        if driver != pole_driver:
                            logger.error(
                                f"Driver position mismatch at {event_name} {year}:\n"
                                f"Driver {driver} marked as P1 but pole was set by {pole_driver}"
                            )
                        gap_to_pole = 0.0
                    else:
                        gap_to_pole = best_lap_time - pole_time
                        
                        if gap_to_pole < 0:
                            logger.error(
                                f"Negative gap detected at {event_name} {year}:\n"
                                f"Driver: {driver} (P{qualifying_position})\n"
                                f"Best lap: {best_lap_time:.3f}s\n"
                                f"Pole time: {pole_time:.3f}s\n"
                                f"Gap: {gap_to_pole:.3f}s\n"
                                f"All laps for {driver}:"
                            )
                            # Print all laps for this driver
                            for _, lap in driver_data.iterrows():
                                logger.error(
                                    f"Lap {lap['LapNumber']}: {lap['LapTimeSeconds']:.3f}s "
                                    f"(Stint: {lap['Stint']}, Track Status: {lap['TrackStatus']})"
                                )
                            gap_to_pole = np.nan  # Set invalid gaps to NaN
                    
                    # Create event summary
                    event_summary = {
                        'round': event_name,
                        'driver': driver,
                        'position': qualifying_position,
                        'gapToPole': gap_to_pole,
                        'teammateGap': gaps[driver],
                        'hasTeammateData': not np.isnan(gaps[driver])
                    }
                    
                    # Find or create driver entry for this year
                    driver_entry = next(
                        (item for item in timeline_data if item['year'] == year and item['driver'] == driver),
                        None
                    )
                    
                    if driver_entry is None:
                        driver_entry = {
                            'year': year,
                            'driver': driver,
                            'team': team,
                            'events': [],
                            'positions': [],
                            'gapToPole_values': [],
                            'teammateGap_values': [],
                            'completeDataCount': 0,
                            'totalEvents': 0
                        }
                        timeline_data.append(driver_entry)
                    
                    driver_entry['events'].append(event_summary)
                    driver_entry['positions'].append(event_summary['position'])
                    driver_entry['totalEvents'] += 1
                    
                    if not np.isnan(gap_to_pole):
                        driver_entry['gapToPole_values'].append(gap_to_pole)
                    if not np.isnan(gaps[driver]):
                        driver_entry['teammateGap_values'].append(gaps[driver])
                        driver_entry['completeDataCount'] += 1
    
    # Calculate final averages and data completeness
    for entry in timeline_data:
        entry['avgQualifyingPosition'] = np.mean(entry['positions'])
        entry['avgGapToPole'] = np.mean(entry['gapToPole_values']) if entry['gapToPole_values'] else np.nan
        entry['avgTeammateGap'] = np.mean(entry['teammateGap_values']) if entry['teammateGap_values'] else np.nan
        entry['dataCompleteness'] = entry['completeDataCount'] / entry['totalEvents'] if entry['totalEvents'] > 0 else 0
        
        # Clean up intermediate calculation fields
        del entry['positions']
        del entry['gapToPole_values']
        del entry['teammateGap_values']
        del entry['completeDataCount']
        del entry['totalEvents']
    
    return timeline_data

# %%
process_qualifying_data(quali_data)
# Out:
# ERROR:__main__:Inconsistency at Belgian Grand Prix 2018:
# Pole Position: L HAMILTON (101.553s)
# Fastest Lap: S VETTEL (101.501s)
# Difference: 0.0519999999999925s
# ERROR:__main__:Negative gap detected at Belgian Grand Prix 2018:
# Driver: K RAIKKONEN (P6.0)
# Best lap: 101.533s
# Pole time: 101.553s
# Gap: -0.020s
# All laps for K RAIKKONEN:
# ERROR:__main__:Lap 2.0: 102.585s (Stint: 1.0, Track Status: 1.0)
# ERROR:__main__:Lap 5.0: 101.627s (Stint: 2.0, Track Status: 1.0)
# ERROR:__main__:Lap 8.0: 101.533s (Stint: 3.0, Track Status: 12.0)
# ERROR:__main__:Lap 12.0: 122.671s (Stint: 5.0, Track Status: 1.0)
# ERROR:__main__:Negative gap detected at Belgian Grand Prix 2018:
# Driver: S VETTEL (P2.0)
# Best lap: 101.501s
# Pole time: 101.553s
# Gap: -0.052s
# All laps for S VETTEL:
# ERROR:__main__:Lap 2.0: 103.035s (Stint: 1.0, Track Status: 1.0)
# ERROR:__main__:Lap 3.0: 147.458s (Stint: 1.0, Track Status: 1.0)
# ERROR:__main__:Lap 4.0: 103.517s (Stint: 1.0, Track Status: 1.0)
# ERROR:__main__:Lap 7.0: 102.133s (Stint: 2.0, Track Status: 1.0)
# ERROR:__main__:Lap 10.0: 101.501s (Stint: 3.0, Track Status: 12.0)
# ERROR:__main__:Lap 14.0: 122.446s (Stint: 5.0, Track Status: 1.0)
# ERROR:__main__:Lap 15.0: 121.188s (Stint: 5.0, Track Status: 1.0)
# ERROR:__main__:Lap 16.0: 118.905s (Stint: 5.0, Track Status: 1.0)
# ERROR:__main__:Lap 17.0: 141.031s (Stint: 5.0, Track Status: 1.0)
# ERROR:__main__:Inconsistency at Hungarian Grand Prix 2018:
# Pole Position: L HAMILTON (91.242s)
# Fastest Lap: S VETTEL (76.666s)
# Difference: 14.576000000000008s
# ERROR:__main__:Negative gap detected at Hungarian Grand Prix 2018:
# Driver: K RAIKKONEN (P3.0)
# Best lap: 77.589s
# Pole time: 91.242s
# Gap: -13.653s
# All laps for K RAIKKONEN:
# ERROR:__main__:Lap 12.0: 77.589s (Stint: 2.0, Track Status: 1.0)
# ERROR:__main__:Lap 16.0: 92.762s (Stint: 4.0, Track Status: 12.0)
# ERROR:__main__:Lap 19.0: 97.769s (Stint: 5.0, Track Status: 1.0)
# ERROR:__main__:Lap 20.0: 97.362s (Stint: 5.0, Track Status: 1.0)
# ERROR:__main__:Lap 21.0: 96.186s (Stint: 5.0, Track Status: 1.0)
# ERROR:__main__:Lap 24.0: 99.062s (Stint: 6.0, Track Status: 1.0)
# ERROR:__main__:Lap 25.0: 127.376s (Stint: 6.0, Track Status: 1.0)
# ERROR:__main__:Negative gap detected at Hungarian Grand Prix 2018:
# Driver: S VETTEL (P4.0)
# Best lap: 76.666s
# Pole time: 91.242s
# Gap: -14.576s
# All laps for S VETTEL:
# ERROR:__main__:Lap 11.0: 76.666s (Stint: 2.0, Track Status: 1.0)
# ERROR:__main__:Lap 14.0: 88.636s (Stint: 3.0, Track Status: 1.0)
# ERROR:__main__:Lap 15.0: 91.130s (Stint: 3.0, Track Status: 1.0)
# ERROR:__main__:Lap 18.0: 99.580s (Stint: 4.0, Track Status: 1.0)
# ERROR:__main__:Lap 19.0: 97.733s (Stint: 4.0, Track Status: 1.0)
# ERROR:__main__:Lap 22.0: 96.938s (Stint: 5.0, Track Status: 1.0)
# ERROR:__main__:Lap 23.0: 96.210s (Stint: 5.0, Track Status: 1.0)
# ERROR:__main__:Negative gap detected at Hungarian Grand Prix 2018:
# Driver: E OCON (P18.0)
# Best lap: 79.142s
# Pole time: 91.242s
# Gap: -12.100s
# All laps for E OCON:
# ERROR:__main__:Lap 11.0: 79.142s (Stint: 3.0, Track Status: 1.0)
# ERROR:__main__:Negative gap detected at Hungarian Grand Prix 2018:
# Driver: K MAGNUSSEN (P9.0)
# Best lap: 78.314s
# Pole time: 91.242s
# Gap: -12.928s
# All laps for K MAGNUSSEN:
# ERROR:__main__:Lap 10.0: 78.314s (Stint: 3.0, Track Status: 1.0)
# ERROR:__main__:Lap 14.0: 92.968s (Stint: 5.0, Track Status: 1.0)
# ERROR:__main__:Lap 18.0: 101.554s (Stint: 7.0, Track Status: 1.0)
# ERROR:__main__:Lap 19.0: 100.550s (Stint: 7.0, Track Status: 1.0)
# ERROR:__main__:Lap 22.0: 99.858s (Stint: 8.0, Track Status: 1.0)
# ERROR:__main__:Lap 23.0: 100.285s (Stint: 8.0, Track Status: 1.0)
# ERROR:__main__:Negative gap detected at Hungarian Grand Prix 2018:
# Driver: V BOTTAS (P2.0)
# Best lap: 77.123s
# Pole time: 91.242s
# Gap: -14.119s
# All laps for V BOTTAS:
# ERROR:__main__:Lap 12.0: 77.123s (Stint: 2.0, Track Status: 1.0)
# ERROR:__main__:Lap 16.0: 92.081s (Stint: 4.0, Track Status: 12.0)
# ERROR:__main__:Lap 19.0: 97.651s (Stint: 5.0, Track Status: 1.0)
# ERROR:__main__:Lap 20.0: 99.156s (Stint: 5.0, Track Status: 1.0)
# ERROR:__main__:Lap 21.0: 97.059s (Stint: 5.0, Track Status: 1.0)
# ERROR:__main__:Lap 24.0: 95.918s (Stint: 6.0, Track Status: 1.0)
# ERROR:__main__:Negative gap detected at Hungarian Grand Prix 2018:
# Driver: D RICCIARDO (P12.0)
# Best lap: 78.540s
# Pole time: 91.242s
# Gap: -12.702s
# All laps for D RICCIARDO:
# ERROR:__main__:Lap 11.0: 78.540s (Stint: 2.0, Track Status: 1.0)
# ERROR:__main__:Lap 15.0: 96.921s (Stint: 4.0, Track Status: 12.0)
# ERROR:__main__:Lap 16.0: 96.933s (Stint: 4.0, Track Status: 12.0)
# ERROR:__main__:Lap 19.0: 98.155s (Stint: 5.0, Track Status: 1.0)
# ERROR:__main__:Lap 20.0: 96.442s (Stint: 5.0, Track Status: 1.0)
# ERROR:__main__:Negative gap detected at Hungarian Grand Prix 2018:
# Driver: M VERSTAPPEN (P7.0)
# Best lap: 76.940s
# Pole time: 91.242s
# Gap: -14.302s
# All laps for M VERSTAPPEN:
# ERROR:__main__:Lap 11.0: 76.940s (Stint: 2.0, Track Status: 1.0)
# ERROR:__main__:Lap 15.0: 91.178s (Stint: 4.0, Track Status: 12.0)
# ERROR:__main__:Lap 18.0: 98.923s (Stint: 5.0, Track Status: 1.0)
# ERROR:__main__:Lap 19.0: 98.032s (Stint: 5.0, Track Status: 1.0)
# ERROR:__main__:Lap 22.0: 104.982s (Stint: 6.0, Track Status: 1.0)
# ERROR:__main__:Lap 23.0: 99.306s (Stint: 6.0, Track Status: 1.0)
# ERROR:__main__:Negative gap detected at Hungarian Grand Prix 2018:
# Driver: C SAINZ (P5.0)
# Best lap: 90.771s
# Pole time: 91.242s
# Gap: -0.471s
# All laps for C SAINZ:
# ERROR:__main__:Lap 15.0: 90.771s (Stint: 4.0, Track Status: 1.0)
# ERROR:__main__:Lap 16.0: 111.379s (Stint: 4.0, Track Status: 12.0)
# ERROR:__main__:Lap 19.0: 99.502s (Stint: 5.0, Track Status: 1.0)
# ERROR:__main__:Lap 20.0: 107.147s (Stint: 5.0, Track Status: 1.0)
# ERROR:__main__:Lap 21.0: 97.966s (Stint: 5.0, Track Status: 1.0)
# ERROR:__main__:Lap 22.0: 96.743s (Stint: 5.0, Track Status: 1.0)
# ERROR:__main__:Lap 23.0: 124.561s (Stint: 5.0, Track Status: 1.0)
# ERROR:__main__:Lap 24.0: 98.443s (Stint: 5.0, Track Status: 1.0)
# ERROR:__main__:Negative gap detected at Hungarian Grand Prix 2018:
# Driver: C LECLERC (P17.0)
# Best lap: 79.008s
# Pole time: 91.242s
# Gap: -12.234s
# All laps for C LECLERC:
# ERROR:__main__:Lap 12.0: 79.008s (Stint: 2.0, Track Status: 1.0)
# ERROR:__main__:Negative gap detected at Hungarian Grand Prix 2018:
# Driver: M ERICSSON (P14.0)
# Best lap: 79.023s
# Pole time: 91.242s
# Gap: -12.219s
# All laps for M ERICSSON:
# ERROR:__main__:Lap 12.0: 79.023s (Stint: 2.0, Track Status: 1.0)
# ERROR:__main__:Lap 16.0: 97.075s (Stint: 4.0, Track Status: 12.0)
# ERROR:__main__:Lap 19.0: 99.914s (Stint: 5.0, Track Status: 1.0)
# ERROR:__main__:Lap 20.0: 99.516s (Stint: 5.0, Track Status: 1.0)
# ERROR:__main__:Lap 21.0: 99.672s (Stint: 5.0, Track Status: 1.0)
# ERROR:__main__:Negative gap detected at Hungarian Grand Prix 2018:
# Driver: B HARTLEY (P8.0)
# Best lap: 78.429s
# Pole time: 91.242s
# Gap: -12.813s
# All laps for B HARTLEY:
# ERROR:__main__:Lap 11.0: 78.429s (Stint: 3.0, Track Status: 1.0)
# ERROR:__main__:Lap 15.0: 92.590s (Stint: 5.0, Track Status: 12.0)
# ERROR:__main__:Lap 16.0: 102.935s (Stint: 5.0, Track Status: 12.0)
# ERROR:__main__:Lap 19.0: 99.820s (Stint: 6.0, Track Status: 1.0)
# ERROR:__main__:Lap 20.0: 100.159s (Stint: 6.0, Track Status: 1.0)
# ERROR:__main__:Lap 23.0: 106.527s (Stint: 7.0, Track Status: 1.0)
# ERROR:__main__:Lap 24.0: 98.128s (Stint: 7.0, Track Status: 1.0)
# ERROR:__main__:Negative gap detected at Hungarian Grand Prix 2018:
# Driver: P GASLY (P6.0)
# Best lap: 78.577s
# Pole time: 91.242s
# Gap: -12.665s
# All laps for P GASLY:
# ERROR:__main__:Lap 11.0: 78.577s (Stint: 2.0, Track Status: 1.0)
# ERROR:__main__:Lap 15.0: 91.286s (Stint: 4.0, Track Status: 12.0)
# ERROR:__main__:Lap 16.0: 101.431s (Stint: 4.0, Track Status: 21.0)
# ERROR:__main__:Lap 19.0: 102.623s (Stint: 5.0, Track Status: 1.0)
# ERROR:__main__:Lap 20.0: 98.012s (Stint: 5.0, Track Status: 1.0)
# ERROR:__main__:Lap 21.0: 98.399s (Stint: 5.0, Track Status: 1.0)
# ERROR:__main__:Lap 24.0: 97.591s (Stint: 6.0, Track Status: 1.0)
# ERROR:__main__:Negative gap detected at Hungarian Grand Prix 2018:
# Driver: L STROLL (P15.0)
# Best lap: 79.584s
# Pole time: 91.242s
# Gap: -11.658s
# All laps for L STROLL:
# ERROR:__main__:Lap 11.0: 79.584s (Stint: 3.0, Track Status: 1.0)
# ERROR:__main__:Negative gap detected at Hungarian Grand Prix 2018:
# Driver: S SIROTKIN (P20.0)
# Best lap: 80.609s
# Pole time: 91.242s
# Gap: -10.633s
# All laps for S SIROTKIN:
# ERROR:__main__:Lap 11.0: 80.609s (Stint: 3.0, Track Status: 1.0)
# ERROR:__main__:Inconsistency at Portuguese Grand Prix 2020:
# Pole Position: L HAMILTON (76.652s)
# Fastest Lap: V BOTTAS (76.466s)
# Difference: 0.18600000000000705s
# ERROR:__main__:Negative gap detected at Portuguese Grand Prix 2020:
# Driver: V BOTTAS (P2.0)
# Best lap: 76.466s
# Pole time: 76.652s
# Gap: -0.186s
# All laps for V BOTTAS:
# ERROR:__main__:Lap 2.0: 77.064s (Stint: 1.0, Track Status: 1.0)
# ERROR:__main__:Lap 3.0: 103.824s (Stint: 1.0, Track Status: 12.0)
# ERROR:__main__:Lap 4.0: 76.945s (Stint: 1.0, Track Status: 1.0)
# ERROR:__main__:Lap 7.0: 76.466s (Stint: 2.0, Track Status: 1.0)
# ERROR:__main__:Lap 10.0: 77.604s (Stint: 3.0, Track Status: 12.0)
# ERROR:__main__:Lap 13.0: 76.986s (Stint: 4.0, Track Status: 1.0)
# ERROR:__main__:Lap 16.0: 76.754s (Stint: 5.0, Track Status: 1.0)
# ERROR:__main__:Inconsistency at Portuguese Grand Prix 2021:
# Pole Position: V BOTTAS (78.348s)
# Fastest Lap: L HAMILTON (77.968s)
# Difference: 0.37999999999999545s
# ERROR:__main__:Negative gap detected at Portuguese Grand Prix 2021:
# Driver: L HAMILTON (P2.0)
# Best lap: 77.968s
# Pole time: 78.348s
# Gap: -0.380s
# All laps for L HAMILTON:
# ERROR:__main__:Lap 2.0: 88.032s (Stint: 1.0, Track Status: 1.0)
# ERROR:__main__:Lap 4.0: 95.593s (Stint: 1.0, Track Status: 1.0)
# ERROR:__main__:Lap 5.0: 79.493s (Stint: 1.0, Track Status: 12.0)
# ERROR:__main__:Lap 8.0: 78.857s (Stint: 2.0, Track Status: 1.0)
# ERROR:__main__:Lap 11.0: 88.059s (Stint: 3.0, Track Status: 1.0)
# ERROR:__main__:Lap 12.0: 77.968s (Stint: 3.0, Track Status: 1.0)
# ERROR:__main__:Lap 15.0: 80.052s (Stint: 4.0, Track Status: 1.0)
# ERROR:__main__:Lap 18.0: 97.037s (Stint: 5.0, Track Status: 1.0)
# ERROR:__main__:Lap 19.0: 78.355s (Stint: 5.0, Track Status: 1.0)
# ERROR:__main__:Lap 22.0: 84.510s (Stint: 6.0, Track Status: 1.0)
# ERROR:__main__:Lap 23.0: 78.645s (Stint: 6.0, Track Status: 1.0)
# [{'year': 2018,
#   'driver': 'K RAIKKONEN',
#   'team': 'Ferrari',
#   'events': [{'round': 'Abu Dhabi Grand Prix',
#     'driver': 'K RAIKKONEN',
#     'position': 4.0,
#     'gapToPole': 0.570999999999998,
#     'teammateGap': 0.23999999999999488,
#     'hasTeammateData': True},
#    {'round': 'Australian Grand Prix',
#     'driver': 'K RAIKKONEN',
#     'position': 2.0,
#     'gapToPole': 0.6640000000000015,
#     'teammateGap': -0.009999999999990905,
#     'hasTeammateData': True},
#    {'round': 'Austrian Grand Prix',
#     'driver': 'K RAIKKONEN',
#     'position': 4.0,
#     'gapToPole': 0.529999999999994,
#     'teammateGap': 0.19599999999999795,
#     'hasTeammateData': True},
#    {'round': 'Azerbaijan Grand Prix',
#     'driver': 'K RAIKKONEN',
#     'position': 6.0,
#     'gapToPole': 0.9919999999999902,
#     'teammateGap': 0.9919999999999902,
#     'hasTeammateData': True},
#    {'round': 'Bahrain Grand Prix',
#     'driver': 'K RAIKKONEN',
#     'position': 2.0,
#     'gapToPole': 0.14300000000000068,
#     'teammateGap': 0.14300000000000068,
#     'hasTeammateData': True},
#    {'round': 'Belgian Grand Prix',
#     'driver': 'K RAIKKONEN',
#     'position': 6.0,
#     'gapToPole': nan,
#     'teammateGap': 0.031999999999996476,
#     'hasTeammateData': True},
#    {'round': 'Brazilian Grand Prix',
#     'driver': 'K RAIKKONEN',
#     'position': 4.0,
#     'gapToPole': 0.17499999999999716,
#     'teammateGap': 0.08200000000000784,
#     'hasTeammateData': True},
#    {'round': 'British Grand Prix',
#     'driver': 'K RAIKKONEN',
#     'position': 3.0,
#     'gapToPole': 0.09799999999999898,
#     'teammateGap': 0.053999999999987836,
#     'hasTeammateData': True},
#    {'round': 'Canadian Grand Prix',
#     'driver': 'K RAIKKONEN',
#     'position': 5.0,
#     'gapToPole': 0.33100000000000307,
#     'teammateGap': 0.33100000000000307,
#     'hasTeammateData': True},
#    {'round': 'Chinese Grand Prix',
#     'driver': 'K RAIKKONEN',
#     'position': 2.0,
#     'gapToPole': 0.0870000000000033,
#     'teammateGap': 0.0870000000000033,
#     'hasTeammateData': True},
#    {'round': 'French Grand Prix',
#     'driver': 'K RAIKKONEN',
#     'position': 6.0,
#     'gapToPole': 0.7430000000000092,
#     'teammateGap': 0.3719999999999999,
#     'hasTeammateData': True},
#    {'round': 'German Grand Prix',
#     'driver': 'K RAIKKONEN',
#     'position': 3.0,
#     'gapToPole': 0.33499999999999375,
#     'teammateGap': 0.33499999999999375,
#     'hasTeammateData': True},
#    {'round': 'Hungarian Grand Prix',
#     'driver': 'K RAIKKONEN',
#     'position': 3.0,
#     'gapToPole': nan,
#     'teammateGap': 0.9230000000000018,
#     'hasTeammateData': True},
#    {'round': 'Italian Grand Prix',
#     'driver': 'K RAIKKONEN',
#     'position': 1.0,
#     'gapToPole': 0.0,
#     'teammateGap': -0.16100000000000136,
#     'hasTeammateData': True},
#    {'round': 'Japanese Grand Prix',
#     'driver': 'K RAIKKONEN',
#     'position': 4.0,
#     'gapToPole': 0.8349999999999937,
#     'teammateGap': 0.3160000000000025,
#     'hasTeammateData': True},
#    {'round': 'Mexican Grand Prix',
#     'driver': 'K RAIKKONEN',
#     'position': 6.0,
#     'gapToPole': 0.570999999999998,
#     'teammateGap': 0.35999999999999943,
#     'hasTeammateData': True},
#    {'round': 'Monaco Grand Prix',
#     'driver': 'K RAIKKONEN',
#     'position': 4.0,
#     'gapToPole': 0.45600000000000307,
#     'teammateGap': 0.22700000000000387,
#     'hasTeammateData': True},
#    {'round': 'Russian Grand Prix',
#     'driver': 'K RAIKKONEN',
#     'position': 4.0,
#     'gapToPole': 0.8499999999999943,
#     'teammateGap': 0.29399999999999693,
#     'hasTeammateData': True},
#    {'round': 'Singapore Grand Prix',
#     'driver': 'K RAIKKONEN',
#     'position': 5.0,
#     'gapToPole': 0.7789999999999964,
#     'teammateGap': 0.16599999999999682,
#     'hasTeammateData': True},
#    {'round': 'Spanish Grand Prix',
#     'driver': 'K RAIKKONEN',
#     'position': 4.0,
#     'gapToPole': 0.43899999999999295,
#     'teammateGap': 0.30699999999998795,
#     'hasTeammateData': True},
#    {'round': 'United States Grand Prix',
#     'driver': 'K RAIKKONEN',
#     'position': 3.0,
#     'gapToPole': 0.07000000000000739,
#     'teammateGap': 0.009000000000000341,
#     'hasTeammateData': True}],
#   'avgQualifyingPosition': 3.857142857142857,
#   'avgGapToPole': 0.45626315789473554,
#   'avgTeammateGap': 0.2521428571428559,
#   'dataCompleteness': 1.0},
#  {'year': 2018,
#   'driver': 'S VETTEL',
#   'team': 'Ferrari',
#   'events': [{'round': 'Abu Dhabi Grand Prix',
#     'driver': 'S VETTEL',
#     'position': 3.0,
#     'gapToPole': 0.33100000000000307,
#     'teammateGap': -0.23999999999999488,
#     'hasTeammateData': True},
#    {'round': 'Australian Grand Prix',
#     'driver': 'S VETTEL',
#     'position': 3.0,
#     'gapToPole': 0.6739999999999924,
#     'teammateGap': 0.009999999999990905,
#     'hasTeammateData': True},
#    {'round': 'Austrian Grand Prix',
#     'driver': 'S VETTEL',
#     'position': 3.0,
#     'gapToPole': 0.3339999999999961,
#     'teammateGap': -0.19599999999999795,
#     'hasTeammateData': True},
#    {'round': 'Azerbaijan Grand Prix',
#     'driver': 'S VETTEL',
#     'position': 1.0,
#     'gapToPole': 0.0,
#     'teammateGap': -0.9919999999999902,
#     'hasTeammateData': True},
#    {'round': 'Bahrain Grand Prix',
#     'driver': 'S VETTEL',
#     'position': 1.0,
#     'gapToPole': 0.0,
#     'teammateGap': -0.14300000000000068,
#     'hasTeammateData': True},
#    {'round': 'Belgian Grand Prix',
#     'driver': 'S VETTEL',
#     'position': 2.0,
#     'gapToPole': nan,
#     'teammateGap': -0.031999999999996476,
#     'hasTeammateData': True},
#    {'round': 'Brazilian Grand Prix',
#     'driver': 'S VETTEL',
#     'position': 2.0,
#     'gapToPole': 0.09299999999998931,
#     'teammateGap': -0.08200000000000784,
#     'hasTeammateData': True},
#    {'round': 'British Grand Prix',
#     'driver': 'S VETTEL',
#     'position': 2.0,
#     'gapToPole': 0.04400000000001114,
#     'teammateGap': -0.053999999999987836,
#     'hasTeammateData': True},
#    {'round': 'Canadian Grand Prix',
#     'driver': 'S VETTEL',
#     'position': 1.0,
#     'gapToPole': 0.0,
#     'teammateGap': -0.33100000000000307,
#     'hasTeammateData': True},
#    {'round': 'Chinese Grand Prix',
#     'driver': 'S VETTEL',
#     'position': 1.0,
#     'gapToPole': 0.0,
#     'teammateGap': -0.0870000000000033,
#     'hasTeammateData': True},
#    {'round': 'French Grand Prix',
#     'driver': 'S VETTEL',
#     'position': 3.0,
#     'gapToPole': 0.3710000000000093,
#     'teammateGap': -0.3719999999999999,
#     'hasTeammateData': True},
#    {'round': 'German Grand Prix',
#     'driver': 'S VETTEL',
#     'position': 1.0,
#     'gapToPole': 0.0,
#     'teammateGap': -0.33499999999999375,
#     'hasTeammateData': True},
#    {'round': 'Hungarian Grand Prix',
#     'driver': 'S VETTEL',
#     'position': 4.0,
#     'gapToPole': nan,
#     'teammateGap': -0.9230000000000018,
#     'hasTeammateData': True},
#    {'round': 'Italian Grand Prix',
#     'driver': 'S VETTEL',
#     'position': 2.0,
#     'gapToPole': 0.16100000000000136,
#     'teammateGap': 0.16100000000000136,
#     'hasTeammateData': True},
#    {'round': 'Japanese Grand Prix',
#     'driver': 'S VETTEL',
#     'position': 9.0,
#     'gapToPole': 0.5189999999999912,
#     'teammateGap': -0.3160000000000025,
#     'hasTeammateData': True},
#    {'round': 'Mexican Grand Prix',
#     'driver': 'S VETTEL',
#     'position': 4.0,
#     'gapToPole': 0.21099999999999852,
#     'teammateGap': -0.35999999999999943,
#     'hasTeammateData': True},
#    {'round': 'Monaco Grand Prix',
#     'driver': 'S VETTEL',
#     'position': 2.0,
#     'gapToPole': 0.2289999999999992,
#     'teammateGap': -0.22700000000000387,
#     'hasTeammateData': True},
#    {'round': 'Russian Grand Prix',
#     'driver': 'S VETTEL',
#     'position': 3.0,
#     'gapToPole': 0.5559999999999974,
#     'teammateGap': -0.29399999999999693,
#     'hasTeammateData': True},
#    {'round': 'Singapore Grand Prix',
#     'driver': 'S VETTEL',
#     'position': 3.0,
#     'gapToPole': 0.6129999999999995,
#     'teammateGap': -0.16599999999999682,
#     'hasTeammateData': True},
#    {'round': 'Spanish Grand Prix',
#     'driver': 'S VETTEL',
#     'position': 3.0,
#     'gapToPole': 0.132000000000005,
#     'teammateGap': -0.30699999999998795,
#     'hasTeammateData': True},
#    {'round': 'United States Grand Prix',
#     'driver': 'S VETTEL',
#     'position': 2.0,
#     'gapToPole': 0.06100000000000705,
#     'teammateGap': -0.009000000000000341,
#     'hasTeammateData': True}],
#   'avgQualifyingPosition': 2.619047619047619,
#   'avgGapToPole': 0.22784210526315793,
#   'avgTeammateGap': -0.2521428571428559,
#   'dataCompleteness': 1.0},
#  {'year': 2018,
#   'driver': 'K MAGNUSSEN',
#   'team': 'Haas F1 Team',
#   'events': [{'round': 'Abu Dhabi Grand Prix',
#     'driver': 'K MAGNUSSEN',
#     'position': 13.0,
#     'gapToPole': 2.5150000000000006,
#     'teammateGap': 1.1170000000000044,
#     'hasTeammateData': True},
#    {'round': 'Australian Grand Prix',
#     'driver': 'K MAGNUSSEN',
#     'position': 6.0,
#     'gapToPole': 2.022999999999996,
#     'teammateGap': -0.15200000000000102,
#     'hasTeammateData': True},
#    {'round': 'Austrian Grand Prix',
#     'driver': 'K MAGNUSSEN',
#     'position': 8.0,
#     'gapToPole': 0.9209999999999994,
#     'teammateGap': 0.15899999999999892,
#     'hasTeammateData': True},
#    {'round': 'Azerbaijan Grand Prix',
#     'driver': 'K MAGNUSSEN',
#     'position': 15.0,
#     'gapToPole': 2.176000000000002,
#     'teammateGap': nan,
#     'hasTeammateData': False},
#    {'round': 'Bahrain Grand Prix',
#     'driver': 'K MAGNUSSEN',
#     'position': 7.0,
#     'gapToPole': 1.4000000000000057,
#     'teammateGap': -1.171999999999997,
#     'hasTeammateData': True},
#    {'round': 'Belgian Grand Prix',
#     'driver': 'K MAGNUSSEN',
#     'position': 9.0,
#     'gapToPole': 1.766999999999996,
#     'teammateGap': 0.2779999999999916,
#     'hasTeammateData': True},
#    {'round': 'Brazilian Grand Prix',
#     'driver': 'K MAGNUSSEN',
#     'position': 11.0,
#     'gapToPole': 1.1929999999999978,
#     'teammateGap': 0.23499999999999943,
#     'hasTeammateData': True},
#    {'round': 'British Grand Prix',
#     'driver': 'K MAGNUSSEN',
#     'position': 7.0,
#     'gapToPole': 1.3520000000000039,
#     'teammateGap': -0.21099999999999852,
#     'hasTeammateData': True},
#    {'round': 'Canadian Grand Prix',
#     'driver': 'K MAGNUSSEN',
#     'position': 11.0,
#     'gapToPole': 1.8419999999999987,
#     'teammateGap': nan,
#     'hasTeammateData': False},
#    {'round': 'Chinese Grand Prix',
#     'driver': 'K MAGNUSSEN',
#     'position': 11.0,
#     'gapToPole': 1.8910000000000053,
#     'teammateGap': 0.4620000000000033,
#     'hasTeammateData': True},
#    {'round': 'French Grand Prix',
#     'driver': 'K MAGNUSSEN',
#     'position': 9.0,
#     'gapToPole': 1.4810000000000088,
#     'teammateGap': 0.038000000000010914,
#     'hasTeammateData': True},
#    {'round': 'German Grand Prix',
#     'driver': 'K MAGNUSSEN',
#     'position': 5.0,
#     'gapToPole': 0.9879999999999995,
#     'teammateGap': -0.3439999999999941,
#     'hasTeammateData': True},
#    {'round': 'Hungarian Grand Prix',
#     'driver': 'K MAGNUSSEN',
#     'position': 9.0,
#     'gapToPole': nan,
#     'teammateGap': -15.336000000000013,
#     'hasTeammateData': True},
#    {'round': 'Italian Grand Prix',
#     'driver': 'K MAGNUSSEN',
#     'position': 11.0,
#     'gapToPole': 2.549999999999997,
#     'teammateGap': 0.7329999999999899,
#     'hasTeammateData': True},
#    {'round': 'Japanese Grand Prix',
#     'driver': 'K MAGNUSSEN',
#     'position': 12.0,
#     'gapToPole': 2.458999999999989,
#     'teammateGap': 0.5409999999999968,
#     'hasTeammateData': True},
#    {'round': 'Mexican Grand Prix',
#     'driver': 'K MAGNUSSEN',
#     'position': 18.0,
#     'gapToPole': 2.8400000000000034,
#     'teammateGap': 0.6880000000000024,
#     'hasTeammateData': True},
#    {'round': 'Monaco Grand Prix',
#     'driver': 'K MAGNUSSEN',
#     'position': 19.0,
#     'gapToPole': 2.5829999999999984,
#     'teammateGap': 0.6650000000000063,
#     'hasTeammateData': True},
#    {'round': 'Russian Grand Prix',
#     'driver': 'K MAGNUSSEN',
#     'position': 5.0,
#     'gapToPole': 1.793999999999997,
#     'teammateGap': -0.3359999999999985,
#     'hasTeammateData': True},
#    {'round': 'Singapore Grand Prix',
#     'driver': 'K MAGNUSSEN',
#     'position': 16.0,
#     'gapToPole': 3.629000000000005,
#     'teammateGap': 1.3240000000000123,
#     'hasTeammateData': True},
#    {'round': 'Spanish Grand Prix',
#     'driver': 'K MAGNUSSEN',
#     'position': 7.0,
#     'gapToPole': 1.4449999999999932,
#     'teammateGap': -0.08100000000000307,
#     'hasTeammateData': True},
#    {'round': 'United States Grand Prix',
#     'driver': 'K MAGNUSSEN',
#     'position': 12.0,
#     'gapToPole': 2.4950000000000045,
#     'teammateGap': 0.4819999999999993,
#     'hasTeammateData': True}],
#   'avgQualifyingPosition': 10.523809523809524,
#   'avgGapToPole': 1.9672,
#   'avgTeammateGap': -0.574210526315789,
#   'dataCompleteness': 0.9047619047619048},
#  {'year': 2018,
#   'driver': 'R GROSJEAN',
#   'team': 'Haas F1 Team',
#   'events': [{'round': 'Abu Dhabi Grand Prix',
#     'driver': 'R GROSJEAN',
#     'position': 7.0,
#     'gapToPole': 1.3979999999999961,
#     'teammateGap': -1.1170000000000044,
#     'hasTeammateData': True},
#    {'round': 'Australian Grand Prix',
#     'driver': 'R GROSJEAN',
#     'position': 7.0,
#     'gapToPole': 2.174999999999997,
#     'teammateGap': 0.15200000000000102,
#     'hasTeammateData': True},
#    {'round': 'Austrian Grand Prix',
#     'driver': 'R GROSJEAN',
#     'position': 6.0,
#     'gapToPole': 0.7620000000000005,
#     'teammateGap': -0.15899999999999892,
#     'hasTeammateData': True},
#    {'round': 'Bahrain Grand Prix',
#     'driver': 'R GROSJEAN',
#     'position': 16.0,
#     'gapToPole': 2.5720000000000027,
#     'teammateGap': 1.171999999999997,
#     'hasTeammateData': True},
#    {'round': 'Belgian Grand Prix',
#     'driver': 'R GROSJEAN',
#     'position': 5.0,
#     'gapToPole': 1.4890000000000043,
#     'teammateGap': -0.2779999999999916,
#     'hasTeammateData': True},
#    {'round': 'Brazilian Grand Prix',
#     'driver': 'R GROSJEAN',
#     'position': 9.0,
#     'gapToPole': 0.9579999999999984,
#     'teammateGap': -0.23499999999999943,
#     'hasTeammateData': True},
#    {'round': 'British Grand Prix',
#     'driver': 'R GROSJEAN',
#     'position': 8.0,
#     'gapToPole': 1.5630000000000024,
#     'teammateGap': 0.21099999999999852,
#     'hasTeammateData': True},
#    {'round': 'Chinese Grand Prix',
#     'driver': 'R GROSJEAN',
#     'position': 10.0,
#     'gapToPole': 1.429000000000002,
#     'teammateGap': -0.4620000000000033,
#     'hasTeammateData': True},
#    {'round': 'French Grand Prix',
#     'driver': 'R GROSJEAN',
#     'position': 10.0,
#     'gapToPole': 1.4429999999999978,
#     'teammateGap': -0.038000000000010914,
#     'hasTeammateData': True},
#    {'round': 'German Grand Prix',
#     'driver': 'R GROSJEAN',
#     'position': 6.0,
#     'gapToPole': 1.3319999999999936,
#     'teammateGap': 0.3439999999999941,
#     'hasTeammateData': True},
#    {'round': 'Hungarian Grand Prix',
#     'driver': 'R GROSJEAN',
#     'position': 10.0,
#     'gapToPole': 2.4080000000000013,
#     'teammateGap': 15.336000000000013,
#     'hasTeammateData': True},
#    {'round': 'Italian Grand Prix',
#     'driver': 'R GROSJEAN',
#     'position': 6.0,
#     'gapToPole': 1.8170000000000073,
#     'teammateGap': -0.7329999999999899,
#     'hasTeammateData': True},
#    {'round': 'Japanese Grand Prix',
#     'driver': 'R GROSJEAN',
#     'position': 5.0,
#     'gapToPole': 1.9179999999999922,
#     'teammateGap': -0.5409999999999968,
#     'hasTeammateData': True},
#    {'round': 'Mexican Grand Prix',
#     'driver': 'R GROSJEAN',
#     'position': 16.0,
#     'gapToPole': 2.152000000000001,
#     'teammateGap': -0.6880000000000024,
#     'hasTeammateData': True},
#    {'round': 'Monaco Grand Prix',
#     'driver': 'R GROSJEAN',
#     'position': 15.0,
#     'gapToPole': 1.9179999999999922,
#     'teammateGap': -0.6650000000000063,
#     'hasTeammateData': True},
#    {'round': 'Russian Grand Prix',
#     'driver': 'R GROSJEAN',
#     'position': 9.0,
#     'gapToPole': 2.1299999999999955,
#     'teammateGap': 0.3359999999999985,
#     'hasTeammateData': True},
#    {'round': 'Singapore Grand Prix',
#     'driver': 'R GROSJEAN',
#     'position': 8.0,
#     'gapToPole': 2.3049999999999926,
#     'teammateGap': -1.3240000000000123,
#     'hasTeammateData': True},
#    {'round': 'Spanish Grand Prix',
#     'driver': 'R GROSJEAN',
#     'position': 10.0,
#     'gapToPole': 1.5259999999999962,
#     'teammateGap': 0.08100000000000307,
#     'hasTeammateData': True},
#    {'round': 'United States Grand Prix',
#     'driver': 'R GROSJEAN',
#     'position': 8.0,
#     'gapToPole': 2.0130000000000052,
#     'teammateGap': -0.4819999999999993,
#     'hasTeammateData': True}],
#   'avgQualifyingPosition': 9.0,
#   'avgGapToPole': 1.7530526315789463,
#   'avgTeammateGap': 0.574210526315789,
#   'dataCompleteness': 1.0},
#  {'year': 2018,
#   'driver': 'F ALONSO',
#   'team': 'McLaren',
#   'events': [{'round': 'Abu Dhabi Grand Prix',
#     'driver': 'F ALONSO',
#     'position': 15.0,
#     'gapToPole': 2.948999999999998,
#     'teammateGap': -0.8340000000000032,
#     'hasTeammateData': True},
#    {'round': 'Austrian Grand Prix',
#     'driver': 'F ALONSO',
#     'position': 14.0,
#     'gapToPole': 1.8350000000000009,
#     'teammateGap': -0.3059999999999974,
#     'hasTeammateData': True},
#    {'round': 'Azerbaijan Grand Prix',
#     'driver': 'F ALONSO',
#     'position': 13.0,
#     'gapToPole': 2.5120000000000005,
#     'teammateGap': -0.4789999999999992,
#     'hasTeammateData': True},
#    {'round': 'Bahrain Grand Prix',
#     'driver': 'F ALONSO',
#     'position': 13.0,
#     'gapToPole': 2.254000000000005,
#     'teammateGap': -0.2669999999999959,
#     'hasTeammateData': True},
#    {'round': 'Belgian Grand Prix',
#     'driver': 'F ALONSO',
#     'position': 17.0,
#     'gapToPole': 3.3640000000000043,
#     'teammateGap': -0.39000000000000057,
#     'hasTeammateData': True},
#    {'round': 'Brazilian Grand Prix',
#     'driver': 'F ALONSO',
#     'position': 18.0,
#     'gapToPole': 2.120999999999995,
#     'teammateGap': -0.19899999999999807,
#     'hasTeammateData': True},
#    {'round': 'British Grand Prix',
#     'driver': 'F ALONSO',
#     'position': 13.0,
#     'gapToPole': 2.247,
#     'teammateGap': -0.9570000000000078,
#     'hasTeammateData': True},
#    {'round': 'Canadian Grand Prix',
#     'driver': 'F ALONSO',
#     'position': 14.0,
#     'gapToPole': 2.0919999999999987,
#     'teammateGap': -0.009000000000000341,
#     'hasTeammateData': True},
#    {'round': 'Chinese Grand Prix',
#     'driver': 'F ALONSO',
#     'position': 13.0,
#     'gapToPole': 2.1370000000000005,
#     'teammateGap': -0.27299999999999613,
#     'hasTeammateData': True},
#    {'round': 'German Grand Prix',
#     'driver': 'F ALONSO',
#     'position': 11.0,
#     'gapToPole': 2.444999999999993,
#     'teammateGap': nan,
#     'hasTeammateData': False},
#    {'round': 'Hungarian Grand Prix',
#     'driver': 'F ALONSO',
#     'position': 11.0,
#     'gapToPole': 3.971999999999994,
#     'teammateGap': nan,
#     'hasTeammateData': False},
#    {'round': 'Italian Grand Prix',
#     'driver': 'F ALONSO',
#     'position': 13.0,
#     'gapToPole': 2.7309999999999945,
#     'teammateGap': -0.23499999999999943,
#     'hasTeammateData': True},
#    {'round': 'Japanese Grand Prix',
#     'driver': 'F ALONSO',
#     'position': 18.0,
#     'gapToPole': 2.812999999999988,
#     'teammateGap': -0.4680000000000035,
#     'hasTeammateData': True},
#    {'round': 'Mexican Grand Prix',
#     'driver': 'F ALONSO',
#     'position': 12.0,
#     'gapToPole': 2.097999999999999,
#     'teammateGap': -0.10899999999999466,
#     'hasTeammateData': True},
#    {'round': 'Monaco Grand Prix',
#     'driver': 'F ALONSO',
#     'position': 7.0,
#     'gapToPole': 1.2999999999999972,
#     'teammateGap': -0.3299999999999983,
#     'hasTeammateData': True},
#    {'round': 'Russian Grand Prix',
#     'driver': 'F ALONSO',
#     'position': 17.0,
#     'gapToPole': 4.117000000000004,
#     'teammateGap': -0.472999999999999,
#     'hasTeammateData': True},
#    {'round': 'Singapore Grand Prix',
#     'driver': 'F ALONSO',
#     'position': 11.0,
#     'gapToPole': 2.6260000000000048,
#     'teammateGap': -1.222999999999999,
#     'hasTeammateData': True},
#    {'round': 'Spanish Grand Prix',
#     'driver': 'F ALONSO',
#     'position': 8.0,
#     'gapToPole': 1.5480000000000018,
#     'teammateGap': -0.6019999999999897,
#     'hasTeammateData': True},
#    {'round': 'United States Grand Prix',
#     'driver': 'F ALONSO',
#     'position': 16.0,
#     'gapToPole': 3.057000000000002,
#     'teammateGap': -0.4410000000000025,
#     'hasTeammateData': True}],
#   'avgQualifyingPosition': 13.368421052631579,
#   'avgGapToPole': 2.5377894736842097,
#   'avgTeammateGap': -0.44676470588235206,
#   'dataCompleteness': 0.8947368421052632},
#  {'year': 2018,
#   'driver': 'S VANDOORNE',
#   'team': 'McLaren',
#   'events': [{'round': 'Abu Dhabi Grand Prix',
#     'driver': 'S VANDOORNE',
#     'position': 18.0,
#     'gapToPole': 3.7830000000000013,
#     'teammateGap': 0.8340000000000032,
#     'hasTeammateData': True},
#    {'round': 'Austrian Grand Prix',
#     'driver': 'S VANDOORNE',
#     'position': 16.0,
#     'gapToPole': 2.1409999999999982,
#     'teammateGap': 0.3059999999999974,
#     'hasTeammateData': True},
#    {'round': 'Azerbaijan Grand Prix',
#     'driver': 'S VANDOORNE',
#     'position': 16.0,
#     'gapToPole': 2.9909999999999997,
#     'teammateGap': 0.4789999999999992,
#     'hasTeammateData': True},
#    {'round': 'Bahrain Grand Prix',
#     'driver': 'S VANDOORNE',
#     'position': 14.0,
#     'gapToPole': 2.521000000000001,
#     'teammateGap': 0.2669999999999959,
#     'hasTeammateData': True},
#    {'round': 'Belgian Grand Prix',
#     'driver': 'S VANDOORNE',
#     'position': 20.0,
#     'gapToPole': 3.754000000000005,
#     'teammateGap': 0.39000000000000057,
#     'hasTeammateData': True},
#    {'round': 'Brazilian Grand Prix',
#     'driver': 'S VANDOORNE',
#     'position': 20.0,
#     'gapToPole': 2.319999999999993,
#     'teammateGap': 0.19899999999999807,
#     'hasTeammateData': True},
#    {'round': 'British Grand Prix',
#     'driver': 'S VANDOORNE',
#     'position': 17.0,
#     'gapToPole': 3.2040000000000077,
#     'teammateGap': 0.9570000000000078,
#     'hasTeammateData': True},
#    {'round': 'Canadian Grand Prix',
#     'driver': 'S VANDOORNE',
#     'position': 15.0,
#     'gapToPole': 2.100999999999999,
#     'teammateGap': 0.009000000000000341,
#     'hasTeammateData': True},
#    {'round': 'Chinese Grand Prix',
#     'driver': 'S VANDOORNE',
#     'position': 14.0,
#     'gapToPole': 2.4099999999999966,
#     'teammateGap': 0.27299999999999613,
#     'hasTeammateData': True},
#    {'round': 'Italian Grand Prix',
#     'driver': 'S VANDOORNE',
#     'position': 20.0,
#     'gapToPole': 2.965999999999994,
#     'teammateGap': 0.23499999999999943,
#     'hasTeammateData': True},
#    {'round': 'Japanese Grand Prix',
#     'driver': 'S VANDOORNE',
#     'position': 19.0,
#     'gapToPole': 3.2809999999999917,
#     'teammateGap': 0.4680000000000035,
#     'hasTeammateData': True},
#    {'round': 'Mexican Grand Prix',
#     'driver': 'S VANDOORNE',
#     'position': 17.0,
#     'gapToPole': 2.2069999999999936,
#     'teammateGap': 0.10899999999999466,
#     'hasTeammateData': True},
#    {'round': 'Monaco Grand Prix',
#     'driver': 'S VANDOORNE',
#     'position': 12.0,
#     'gapToPole': 1.6299999999999955,
#     'teammateGap': 0.3299999999999983,
#     'hasTeammateData': True},
#    {'round': 'Russian Grand Prix',
#     'driver': 'S VANDOORNE',
#     'position': 19.0,
#     'gapToPole': 4.590000000000003,
#     'teammateGap': 0.472999999999999,
#     'hasTeammateData': True},
#    {'round': 'Singapore Grand Prix',
#     'driver': 'S VANDOORNE',
#     'position': 18.0,
#     'gapToPole': 3.8490000000000038,
#     'teammateGap': 1.222999999999999,
#     'hasTeammateData': True},
#    {'round': 'Spanish Grand Prix',
#     'driver': 'S VANDOORNE',
#     'position': 11.0,
#     'gapToPole': 2.1499999999999915,
#     'teammateGap': 0.6019999999999897,
#     'hasTeammateData': True},
#    {'round': 'United States Grand Prix',
#     'driver': 'S VANDOORNE',
#     'position': 20.0,
#     'gapToPole': 3.4980000000000047,
#     'teammateGap': 0.4410000000000025,
#     'hasTeammateData': True}],
#   'avgQualifyingPosition': 16.823529411764707,
#   'avgGapToPole': 2.9056470588235284,
#   'avgTeammateGap': 0.44676470588235206,
#   'dataCompleteness': 1.0},
#  {'year': 2018,
#   'driver': 'L HAMILTON',
#   'team': 'Mercedes',
#   'events': [{'round': 'Abu Dhabi Grand Prix',
#     'driver': 'L HAMILTON',
#     'position': 1.0,
#     'gapToPole': 0.0,
#     'teammateGap': -0.16200000000000614,
#     'hasTeammateData': True},
#    {'round': 'Australian Grand Prix',
#     'driver': 'L HAMILTON',
#     'position': 1.0,
#     'gapToPole': 0.0,
#     'teammateGap': nan,
#     'hasTeammateData': False},
#    {'round': 'Austrian Grand Prix',
#     'driver': 'L HAMILTON',
#     'position': 2.0,
#     'gapToPole': 0.01899999999999835,
#     'teammateGap': 0.01899999999999835,
#     'hasTeammateData': True},
#    {'round': 'Azerbaijan Grand Prix',
#     'driver': 'L HAMILTON',
#     'position': 2.0,
#     'gapToPole': 0.17900000000000205,
#     'teammateGap': -0.1599999999999966,
#     'hasTeammateData': True},
#    {'round': 'Bahrain Grand Prix',
#     'driver': 'L HAMILTON',
#     'position': 4.0,
#     'gapToPole': 0.26200000000000045,
#     'teammateGap': 0.09600000000000364,
#     'hasTeammateData': True},
#    {'round': 'Belgian Grand Prix',
#     'driver': 'L HAMILTON',
#     'position': 1.0,
#     'gapToPole': 0.0,
#     'teammateGap': -0.6380000000000052,
#     'hasTeammateData': True},
#    {'round': 'Brazilian Grand Prix',
#     'driver': 'L HAMILTON',
#     'position': 1.0,
#     'gapToPole': 0.0,
#     'teammateGap': -0.1599999999999966,
#     'hasTeammateData': True},
#    {'round': 'British Grand Prix',
#     'driver': 'L HAMILTON',
#     'position': 1.0,
#     'gapToPole': 0.0,
#     'teammateGap': -0.32500000000000284,
#     'hasTeammateData': True},
#    {'round': 'Canadian Grand Prix',
#     'driver': 'L HAMILTON',
#     'position': 4.0,
#     'gapToPole': 0.23199999999999932,
#     'teammateGap': 0.1389999999999958,
#     'hasTeammateData': True},
#    {'round': 'Chinese Grand Prix',
#     'driver': 'L HAMILTON',
#     'position': 4.0,
#     'gapToPole': 0.5799999999999983,
#     'teammateGap': 0.04999999999999716,
#     'hasTeammateData': True},
#    {'round': 'French Grand Prix',
#     'driver': 'L HAMILTON',
#     'position': 1.0,
#     'gapToPole': 0.0,
#     'teammateGap': -0.11800000000000921,
#     'hasTeammateData': True},
#    {'round': 'Hungarian Grand Prix',
#     'driver': 'L HAMILTON',
#     'position': 1.0,
#     'gapToPole': 0.0,
#     'teammateGap': 14.119,
#     'hasTeammateData': True},
#    {'round': 'Italian Grand Prix',
#     'driver': 'L HAMILTON',
#     'position': 3.0,
#     'gapToPole': 0.17499999999999716,
#     'teammateGap': -0.362000000000009,
#     'hasTeammateData': True},
#    {'round': 'Japanese Grand Prix',
#     'driver': 'L HAMILTON',
#     'position': 1.0,
#     'gapToPole': 0.0,
#     'teammateGap': -0.22699999999998965,
#     'hasTeammateData': True},
#    {'round': 'Mexican Grand Prix',
#     'driver': 'L HAMILTON',
#     'position': 3.0,
#     'gapToPole': 0.13500000000000512,
#     'teammateGap': -0.26599999999999113,
#     'hasTeammateData': True},
#    {'round': 'Monaco Grand Prix',
#     'driver': 'L HAMILTON',
#     'position': 3.0,
#     'gapToPole': 0.42199999999999704,
#     'teammateGap': -0.20900000000000318,
#     'hasTeammateData': True},
#    {'round': 'Russian Grand Prix',
#     'driver': 'L HAMILTON',
#     'position': 2.0,
#     'gapToPole': 0.14499999999999602,
#     'teammateGap': 0.14499999999999602,
#     'hasTeammateData': True},
#    {'round': 'Singapore Grand Prix',
#     'driver': 'L HAMILTON',
#     'position': 1.0,
#     'gapToPole': 0.0,
#     'teammateGap': -0.6869999999999976,
#     'hasTeammateData': True},
#    {'round': 'Spanish Grand Prix',
#     'driver': 'L HAMILTON',
#     'position': 1.0,
#     'gapToPole': 0.0,
#     'teammateGap': -0.03999999999999204,
#     'hasTeammateData': True},
#    {'round': 'United States Grand Prix',
#     'driver': 'L HAMILTON',
#     'position': 1.0,
#     'gapToPole': 0.0,
#     'teammateGap': -0.3790000000000049,
#     'hasTeammateData': True}],
#   'avgQualifyingPosition': 1.9,
#   'avgGapToPole': 0.10744999999999968,
#   'avgTeammateGap': 0.5702631578947361,
#   'dataCompleteness': 0.95},
#  {'year': 2018,
#   'driver': 'V BOTTAS',
#   'team': 'Mercedes',
#   'events': [{'round': 'Abu Dhabi Grand Prix',
#     'driver': 'V BOTTAS',
#     'position': 2.0,
#     'gapToPole': 0.16200000000000614,
#     'teammateGap': 0.16200000000000614,
#     'hasTeammateData': True},
#    {'round': 'Austrian Grand Prix',
#     'driver': 'V BOTTAS',
#     'position': 1.0,
#     'gapToPole': 0.0,
#     'teammateGap': -0.01899999999999835,
#     'hasTeammateData': True},
#    {'round': 'Azerbaijan Grand Prix',
#     'driver': 'V BOTTAS',
#     'position': 3.0,
#     'gapToPole': 0.33899999999999864,
#     'teammateGap': 0.1599999999999966,
#     'hasTeammateData': True},
#    {'round': 'Bahrain Grand Prix',
#     'driver': 'V BOTTAS',
#     'position': 3.0,
#     'gapToPole': 0.16599999999999682,
#     'teammateGap': -0.09600000000000364,
#     'hasTeammateData': True},
#    {'round': 'Belgian Grand Prix',
#     'driver': 'V BOTTAS',
#     'position': 10.0,
#     'gapToPole': 0.6380000000000052,
#     'teammateGap': 0.6380000000000052,
#     'hasTeammateData': True},
#    {'round': 'Brazilian Grand Prix',
#     'driver': 'V BOTTAS',
#     'position': 3.0,
#     'gapToPole': 0.1599999999999966,
#     'teammateGap': 0.1599999999999966,
#     'hasTeammateData': True},
#    {'round': 'British Grand Prix',
#     'driver': 'V BOTTAS',
#     'position': 4.0,
#     'gapToPole': 0.32500000000000284,
#     'teammateGap': 0.32500000000000284,
#     'hasTeammateData': True},
#    {'round': 'Canadian Grand Prix',
#     'driver': 'V BOTTAS',
#     'position': 2.0,
#     'gapToPole': 0.09300000000000352,
#     'teammateGap': -0.1389999999999958,
#     'hasTeammateData': True},
#    {'round': 'Chinese Grand Prix',
#     'driver': 'V BOTTAS',
#     'position': 3.0,
#     'gapToPole': 0.5300000000000011,
#     'teammateGap': -0.04999999999999716,
#     'hasTeammateData': True},
#    {'round': 'French Grand Prix',
#     'driver': 'V BOTTAS',
#     'position': 2.0,
#     'gapToPole': 0.11800000000000921,
#     'teammateGap': 0.11800000000000921,
#     'hasTeammateData': True},
#    {'round': 'German Grand Prix',
#     'driver': 'V BOTTAS',
#     'position': 2.0,
#     'gapToPole': 0.20399999999999352,
#     'teammateGap': nan,
#     'hasTeammateData': False},
#    {'round': 'Hungarian Grand Prix',
#     'driver': 'V BOTTAS',
#     'position': 2.0,
#     'gapToPole': nan,
#     'teammateGap': -14.119,
#     'hasTeammateData': True},
#    {'round': 'Italian Grand Prix',
#     'driver': 'V BOTTAS',
#     'position': 4.0,
#     'gapToPole': 0.5370000000000061,
#     'teammateGap': 0.362000000000009,
#     'hasTeammateData': True},
#    {'round': 'Japanese Grand Prix',
#     'driver': 'V BOTTAS',
#     'position': 2.0,
#     'gapToPole': 0.22699999999998965,
#     'teammateGap': 0.22699999999998965,
#     'hasTeammateData': True},
#    {'round': 'Mexican Grand Prix',
#     'driver': 'V BOTTAS',
#     'position': 5.0,
#     'gapToPole': 0.40099999999999625,
#     'teammateGap': 0.26599999999999113,
#     'hasTeammateData': True},
#    {'round': 'Monaco Grand Prix',
#     'driver': 'V BOTTAS',
#     'position': 5.0,
#     'gapToPole': 0.6310000000000002,
#     'teammateGap': 0.20900000000000318,
#     'hasTeammateData': True},
#    {'round': 'Russian Grand Prix',
#     'driver': 'V BOTTAS',
#     'position': 1.0,
#     'gapToPole': 0.0,
#     'teammateGap': -0.14499999999999602,
#     'hasTeammateData': True},
#    {'round': 'Singapore Grand Prix',
#     'driver': 'V BOTTAS',
#     'position': 4.0,
#     'gapToPole': 0.6869999999999976,
#     'teammateGap': 0.6869999999999976,
#     'hasTeammateData': True},
#    {'round': 'Spanish Grand Prix',
#     'driver': 'V BOTTAS',
#     'position': 2.0,
#     'gapToPole': 0.03999999999999204,
#     'teammateGap': 0.03999999999999204,
#     'hasTeammateData': True},
#    {'round': 'United States Grand Prix',
#     'driver': 'V BOTTAS',
#     'position': 4.0,
#     'gapToPole': 0.3790000000000049,
#     'teammateGap': 0.3790000000000049,
#     'hasTeammateData': True}],
#   'avgQualifyingPosition': 3.2,
#   'avgGapToPole': 0.29668421052631583,
#   'avgTeammateGap': -0.5702631578947361,
#   'dataCompleteness': 0.95},
#  {'year': 2018,
#   'driver': 'E OCON',
#   'team': 'Racing Point',
#   'events': [{'round': 'Abu Dhabi Grand Prix',
#     'driver': 'E OCON',
#     'position': 9.0,
#     'gapToPole': 1.7460000000000093,
#     'teammateGap': -0.7149999999999892,
#     'hasTeammateData': True},
#    {'round': 'Austrian Grand Prix',
#     'driver': 'E OCON',
#     'position': 11.0,
#     'gapToPole': 1.7149999999999963,
#     'teammateGap': -0.4339999999999975,
#     'hasTeammateData': True},
#    {'round': 'Azerbaijan Grand Prix',
#     'driver': 'E OCON',
#     'position': 7.0,
#     'gapToPole': 1.0249999999999915,
#     'teammateGap': -0.02400000000000091,
#     'hasTeammateData': True},
#    {'round': 'Bahrain Grand Prix',
#     'driver': 'E OCON',
#     'position': 9.0,
#     'gapToPole': 1.9159999999999968,
#     'teammateGap': -0.2820000000000107,
#     'hasTeammateData': True},
#    {'round': 'Belgian Grand Prix',
#     'driver': 'E OCON',
#     'position': 3.0,
#     'gapToPole': 1.7490000000000094,
#     'teammateGap': 0.2880000000000109,
#     'hasTeammateData': True},
#    {'round': 'Brazilian Grand Prix',
#     'driver': 'E OCON',
#     'position': 13.0,
#     'gapToPole': 1.48899999999999,
#     'teammateGap': 0.028999999999996362,
#     'hasTeammateData': True},
#    {'round': 'British Grand Prix',
#     'driver': 'E OCON',
#     'position': 10.0,
#     'gapToPole': 1.9510000000000076,
#     'teammateGap': -0.08499999999999375,
#     'hasTeammateData': True},
#    {'round': 'Canadian Grand Prix',
#     'driver': 'E OCON',
#     'position': 8.0,
#     'gapToPole': 1.3200000000000074,
#     'teammateGap': -0.31099999999999284,
#     'hasTeammateData': True},
#    {'round': 'Chinese Grand Prix',
#     'driver': 'E OCON',
#     'position': 12.0,
#     'gapToPole': 1.9620000000000033,
#     'teammateGap': 0.2990000000000066,
#     'hasTeammateData': True},
#    {'round': 'French Grand Prix',
#     'driver': 'E OCON',
#     'position': 11.0,
#     'gapToPole': 2.0460000000000065,
#     'teammateGap': -0.3789999999999907,
#     'hasTeammateData': True},
#    {'round': 'Hungarian Grand Prix',
#     'driver': 'E OCON',
#     'position': 18.0,
#     'gapToPole': nan,
#     'teammateGap': nan,
#     'hasTeammateData': False},
#    {'round': 'Italian Grand Prix',
#     'driver': 'E OCON',
#     'position': 8.0,
#     'gapToPole': 1.980000000000004,
#     'teammateGap': -0.7890000000000015,
#     'hasTeammateData': True},
#    {'round': 'Japanese Grand Prix',
#     'driver': 'E OCON',
#     'position': 8.0,
#     'gapToPole': 1.7779999999999916,
#     'teammateGap': -0.028999999999996362,
#     'hasTeammateData': True},
#    {'round': 'Mexican Grand Prix',
#     'driver': 'E OCON',
#     'position': 11.0,
#     'gapToPole': 1.492999999999995,
#     'teammateGap': 0.009999999999990905,
#     'hasTeammateData': True},
#    {'round': 'Monaco Grand Prix',
#     'driver': 'E OCON',
#     'position': 6.0,
#     'gapToPole': 1.2510000000000048,
#     'teammateGap': -0.09299999999998931,
#     'hasTeammateData': True},
#    {'round': 'Russian Grand Prix',
#     'driver': 'E OCON',
#     'position': 6.0,
#     'gapToPole': 2.0259999999999962,
#     'teammateGap': -0.15000000000000568,
#     'hasTeammateData': True},
#    {'round': 'Singapore Grand Prix',
#     'driver': 'E OCON',
#     'position': 9.0,
#     'gapToPole': 2.3499999999999943,
#     'teammateGap': 0.37999999999999545,
#     'hasTeammateData': True},
#    {'round': 'Spanish Grand Prix',
#     'driver': 'E OCON',
#     'position': 13.0,
#     'gapToPole': 2.522999999999996,
#     'teammateGap': -0.04399999999999693,
#     'hasTeammateData': True},
#    {'round': 'United States Grand Prix',
#     'driver': 'E OCON',
#     'position': 6.0,
#     'gapToPole': 1.9080000000000013,
#     'teammateGap': -0.38000000000000966,
#     'hasTeammateData': True}],
#   'avgQualifyingPosition': 9.368421052631579,
#   'avgGapToPole': 1.7904444444444445,
#   'avgTeammateGap': -0.1504999999999986,
#   'dataCompleteness': 0.9473684210526315},
#  {'year': 2018,
#   'driver': 'S PEREZ',
#   'team': 'Racing Point',
#   'events': [{'round': 'Abu Dhabi Grand Prix',
#     'driver': 'S PEREZ',
#     'position': 14.0,
#     'gapToPole': 2.4609999999999985,
#     'teammateGap': 0.7149999999999892,
#     'hasTeammateData': True},
#    {'round': 'Austrian Grand Prix',
#     'driver': 'S PEREZ',
#     'position': 17.0,
#     'gapToPole': 2.148999999999994,
#     'teammateGap': 0.4339999999999975,
#     'hasTeammateData': True},
#    {'round': 'Azerbaijan Grand Prix',
#     'driver': 'S PEREZ',
#     'position': 8.0,
#     'gapToPole': 1.0489999999999924,
#     'teammateGap': 0.02400000000000091,
#     'hasTeammateData': True},
#    {'round': 'Bahrain Grand Prix',
#     'driver': 'S PEREZ',
#     'position': 12.0,
#     'gapToPole': 2.1980000000000075,
#     'teammateGap': 0.2820000000000107,
#     'hasTeammateData': True},
#    {'round': 'Belgian Grand Prix',
#     'driver': 'S PEREZ',
#     'position': 4.0,
#     'gapToPole': 1.4609999999999985,
#     'teammateGap': -0.2880000000000109,
#     'hasTeammateData': True},
#    {'round': 'Brazilian Grand Prix',
#     'driver': 'S PEREZ',
#     'position': 12.0,
#     'gapToPole': 1.4599999999999937,
#     'teammateGap': -0.028999999999996362,
#     'hasTeammateData': True},
#    {'round': 'British Grand Prix',
#     'driver': 'S PEREZ',
#     'position': 12.0,
#     'gapToPole': 2.0360000000000014,
#     'teammateGap': 0.08499999999999375,
#     'hasTeammateData': True},
#    {'round': 'Canadian Grand Prix',
#     'driver': 'S PEREZ',
#     'position': 10.0,
#     'gapToPole': 1.6310000000000002,
#     'teammateGap': 0.31099999999999284,
#     'hasTeammateData': True},
#    {'round': 'Chinese Grand Prix',
#     'driver': 'S PEREZ',
#     'position': 8.0,
#     'gapToPole': 1.6629999999999967,
#     'teammateGap': -0.2990000000000066,
#     'hasTeammateData': True},
#    {'round': 'French Grand Prix',
#     'driver': 'S PEREZ',
#     'position': 13.0,
#     'gapToPole': 2.424999999999997,
#     'teammateGap': 0.3789999999999907,
#     'hasTeammateData': True},
#    {'round': 'German Grand Prix',
#     'driver': 'S PEREZ',
#     'position': 10.0,
#     'gapToPole': 1.5619999999999976,
#     'teammateGap': nan,
#     'hasTeammateData': False},
#    {'round': 'Italian Grand Prix',
#     'driver': 'S PEREZ',
#     'position': 16.0,
#     'gapToPole': 2.7690000000000055,
#     'teammateGap': 0.7890000000000015,
#     'hasTeammateData': True},
#    {'round': 'Japanese Grand Prix',
#     'driver': 'S PEREZ',
#     'position': 10.0,
#     'gapToPole': 1.806999999999988,
# ...
#     'hasTeammateData': True},
#    {'round': 'Monaco Grand Prix',
#     'driver': 'N MAZEPIN',
#     'position': 19.0,
#     'gapToPole': 2.6119999999999948,
#     'teammateGap': nan,
#     'hasTeammateData': False},
#    {'round': 'Portuguese Grand Prix',
#     'driver': 'N MAZEPIN',
#     'position': 20.0,
#     'gapToPole': 2.564000000000007,
#     'teammateGap': 0.46000000000000796,
#     'hasTeammateData': True},
#    {'round': 'Spanish Grand Prix',
#     'driver': 'N MAZEPIN',
#     'position': 20.0,
#     'gapToPole': 3.0660000000000025,
#     'teammateGap': 0.6899999999999977,
#     'hasTeammateData': True}],
#   'avgQualifyingPosition': 19.142857142857142,
#   'avgGapToPole': 3.069714285714286,
#   'avgTeammateGap': 0.5306666666666686,
#   'dataCompleteness': 0.8571428571428571},
#  {'year': 2021,
#   'driver': 'D RICCIARDO',
#   'team': 'McLaren',
#   'events': [{'round': 'Azerbaijan Grand Prix',
#     'driver': 'D RICCIARDO',
#     'position': 13.0,
#     'gapToPole': 1.0859999999999985,
#     'teammateGap': 0.5570000000000022,
#     'hasTeammateData': True},
#    {'round': 'Bahrain Grand Prix',
#     'driver': 'D RICCIARDO',
#     'position': 6.0,
#     'gapToPole': 0.9300000000000068,
#     'teammateGap': -0.046999999999997044,
#     'hasTeammateData': True},
#    {'round': 'Emilia Romagna Grand Prix',
#     'driver': 'D RICCIARDO',
#     'position': 6.0,
#     'gapToPole': 0.41499999999999204,
#     'teammateGap': 0.10799999999998988,
#     'hasTeammateData': True},
#    {'round': 'French Grand Prix',
#     'driver': 'D RICCIARDO',
#     'position': 10.0,
#     'gapToPole': 1.3920000000000101,
#     'teammateGap': 0.13000000000000966,
#     'hasTeammateData': True},
#    {'round': 'Monaco Grand Prix',
#     'driver': 'D RICCIARDO',
#     'position': 12.0,
#     'gapToPole': 1.2519999999999953,
#     'teammateGap': 0.9779999999999944,
#     'hasTeammateData': True},
#    {'round': 'Portuguese Grand Prix',
#     'driver': 'D RICCIARDO',
#     'position': 16.0,
#     'gapToPole': 1.4909999999999997,
#     'teammateGap': 1.358000000000004,
#     'hasTeammateData': True},
#    {'round': 'Spanish Grand Prix',
#     'driver': 'D RICCIARDO',
#     'position': 7.0,
#     'gapToPole': 0.8810000000000002,
#     'teammateGap': -0.07399999999999807,
#     'hasTeammateData': True}],
#   'avgQualifyingPosition': 10.0,
#   'avgGapToPole': 1.0638571428571433,
#   'avgTeammateGap': 0.4300000000000007,
#   'dataCompleteness': 1.0},
#  {'year': 2021,
#   'driver': 'L NORRIS',
#   'team': 'McLaren',
#   'events': [{'round': 'Azerbaijan Grand Prix',
#     'driver': 'L NORRIS',
#     'position': 6.0,
#     'gapToPole': 0.5289999999999964,
#     'teammateGap': -0.5570000000000022,
#     'hasTeammateData': True},
#    {'round': 'Bahrain Grand Prix',
#     'driver': 'L NORRIS',
#     'position': 7.0,
#     'gapToPole': 0.9770000000000039,
#     'teammateGap': 0.046999999999997044,
#     'hasTeammateData': True},
#    {'round': 'Emilia Romagna Grand Prix',
#     'driver': 'L NORRIS',
#     'position': 7.0,
#     'gapToPole': 0.30700000000000216,
#     'teammateGap': -0.10799999999998988,
#     'hasTeammateData': True},
#    {'round': 'French Grand Prix',
#     'driver': 'L NORRIS',
#     'position': 8.0,
#     'gapToPole': 1.2620000000000005,
#     'teammateGap': -0.13000000000000966,
#     'hasTeammateData': True},
#    {'round': 'Monaco Grand Prix',
#     'driver': 'L NORRIS',
#     'position': 5.0,
#     'gapToPole': 0.2740000000000009,
#     'teammateGap': -0.9779999999999944,
#     'hasTeammateData': True},
#    {'round': 'Portuguese Grand Prix',
#     'driver': 'L NORRIS',
#     'position': 7.0,
#     'gapToPole': 0.13299999999999557,
#     'teammateGap': -1.358000000000004,
#     'hasTeammateData': True},
#    {'round': 'Spanish Grand Prix',
#     'driver': 'L NORRIS',
#     'position': 9.0,
#     'gapToPole': 0.9549999999999983,
#     'teammateGap': 0.07399999999999807,
#     'hasTeammateData': True}],
#   'avgQualifyingPosition': 7.0,
#   'avgGapToPole': 0.6338571428571426,
#   'avgTeammateGap': -0.4300000000000007,
#   'dataCompleteness': 1.0},
#  {'year': 2021,
#   'driver': 'L HAMILTON',
#   'team': 'Mercedes',
#   'events': [{'round': 'Azerbaijan Grand Prix',
#     'driver': 'L HAMILTON',
#     'position': 2.0,
#     'gapToPole': 0.23199999999999932,
#     'teammateGap': -0.6559999999999917,
#     'hasTeammateData': True},
#    {'round': 'Bahrain Grand Prix',
#     'driver': 'L HAMILTON',
#     'position': 2.0,
#     'gapToPole': 0.38800000000000523,
#     'teammateGap': -0.2009999999999934,
#     'hasTeammateData': True},
#    {'round': 'Emilia Romagna Grand Prix',
#     'driver': 'L HAMILTON',
#     'position': 1.0,
#     'gapToPole': 0.0,
#     'teammateGap': -0.2609999999999957,
#     'hasTeammateData': True},
#    {'round': 'French Grand Prix',
#     'driver': 'L HAMILTON',
#     'position': 2.0,
#     'gapToPole': 0.2580000000000098,
#     'teammateGap': -0.1280000000000001,
#     'hasTeammateData': True},
#    {'round': 'Monaco Grand Prix',
#     'driver': 'L HAMILTON',
#     'position': 7.0,
#     'gapToPole': 0.7489999999999952,
#     'teammateGap': 0.4939999999999998,
#     'hasTeammateData': True},
#    {'round': 'Portuguese Grand Prix',
#     'driver': 'L HAMILTON',
#     'position': 2.0,
#     'gapToPole': nan,
#     'teammateGap': -0.37999999999999545,
#     'hasTeammateData': True},
#    {'round': 'Spanish Grand Prix',
#     'driver': 'L HAMILTON',
#     'position': 1.0,
#     'gapToPole': 0.0,
#     'teammateGap': -0.132000000000005,
#     'hasTeammateData': True}],
#   'avgQualifyingPosition': 2.4285714285714284,
#   'avgGapToPole': 0.2711666666666683,
#   'avgTeammateGap': -0.18057142857142594,
#   'dataCompleteness': 1.0},
#  {'year': 2021,
#   'driver': 'V BOTTAS',
#   'team': 'Mercedes',
#   'events': [{'round': 'Azerbaijan Grand Prix',
#     'driver': 'V BOTTAS',
#     'position': 10.0,
#     'gapToPole': 0.887999999999991,
#     'teammateGap': 0.6559999999999917,
#     'hasTeammateData': True},
#    {'round': 'Bahrain Grand Prix',
#     'driver': 'V BOTTAS',
#     'position': 3.0,
#     'gapToPole': 0.5889999999999986,
#     'teammateGap': 0.2009999999999934,
#     'hasTeammateData': True},
#    {'round': 'Emilia Romagna Grand Prix',
#     'driver': 'V BOTTAS',
#     'position': 8.0,
#     'gapToPole': 0.2609999999999957,
#     'teammateGap': 0.2609999999999957,
#     'hasTeammateData': True},
#    {'round': 'French Grand Prix',
#     'driver': 'V BOTTAS',
#     'position': 3.0,
#     'gapToPole': 0.3860000000000099,
#     'teammateGap': 0.1280000000000001,
#     'hasTeammateData': True},
#    {'round': 'Monaco Grand Prix',
#     'driver': 'V BOTTAS',
#     'position': 3.0,
#     'gapToPole': 0.25499999999999545,
#     'teammateGap': -0.4939999999999998,
#     'hasTeammateData': True},
#    {'round': 'Portuguese Grand Prix',
#     'driver': 'V BOTTAS',
#     'position': 1.0,
#     'gapToPole': 0.0,
#     'teammateGap': 0.37999999999999545,
#     'hasTeammateData': True},
#    {'round': 'Spanish Grand Prix',
#     'driver': 'V BOTTAS',
#     'position': 3.0,
#     'gapToPole': 0.132000000000005,
#     'teammateGap': 0.132000000000005,
#     'hasTeammateData': True}],
#   'avgQualifyingPosition': 4.428571428571429,
#   'avgGapToPole': 0.3587142857142851,
#   'avgTeammateGap': 0.18057142857142594,
#   'dataCompleteness': 1.0},
#  {'year': 2021,
#   'driver': 'M VERSTAPPEN',
#   'team': 'Red Bull Racing',
#   'events': [{'round': 'Azerbaijan Grand Prix',
#     'driver': 'M VERSTAPPEN',
#     'position': 3.0,
#     'gapToPole': 0.34499999999999886,
#     'teammateGap': -0.06699999999999307,
#     'hasTeammateData': True},
#    {'round': 'Bahrain Grand Prix',
#     'driver': 'M VERSTAPPEN',
#     'position': 1.0,
#     'gapToPole': 0.0,
#     'teammateGap': -1.6620000000000061,
#     'hasTeammateData': True},
#    {'round': 'Emilia Romagna Grand Prix',
#     'driver': 'M VERSTAPPEN',
#     'position': 3.0,
#     'gapToPole': 0.0870000000000033,
#     'teammateGap': 0.05200000000000671,
#     'hasTeammateData': True},
#    {'round': 'French Grand Prix',
#     'driver': 'M VERSTAPPEN',
#     'position': 1.0,
#     'gapToPole': 0.0,
#     'teammateGap': -0.4549999999999983,
#     'hasTeammateData': True},
#    {'round': 'Monaco Grand Prix',
#     'driver': 'M VERSTAPPEN',
#     'position': 2.0,
#     'gapToPole': 0.22999999999998977,
#     'teammateGap': -0.44300000000001205,
#     'hasTeammateData': True},
#    {'round': 'Portuguese Grand Prix',
#     'driver': 'M VERSTAPPEN',
#     'position': 3.0,
#     'gapToPole': 0.3020000000000067,
#     'teammateGap': -0.19499999999999318,
#     'hasTeammateData': True},
#    {'round': 'Spanish Grand Prix',
#     'driver': 'M VERSTAPPEN',
#     'position': 2.0,
#     'gapToPole': 0.036000000000001364,
#     'teammateGap': -0.8919999999999959,
#     'hasTeammateData': True}],
#   'avgQualifyingPosition': 2.142857142857143,
#   'avgGapToPole': 0.14285714285714285,
#   'avgTeammateGap': -0.523142857142856,
#   'dataCompleteness': 1.0},
#  {'year': 2021,
#   'driver': 'S PEREZ',
#   'team': 'Red Bull Racing',
#   'events': [{'round': 'Azerbaijan Grand Prix',
#     'driver': 'S PEREZ',
#     'position': 7.0,
#     'gapToPole': 0.41199999999999193,
#     'teammateGap': 0.06699999999999307,
#     'hasTeammateData': True},
#    {'round': 'Bahrain Grand Prix',
#     'driver': 'S PEREZ',
#     'position': 11.0,
#     'gapToPole': 1.6620000000000061,
#     'teammateGap': 1.6620000000000061,
#     'hasTeammateData': True},
#    {'round': 'Emilia Romagna Grand Prix',
#     'driver': 'S PEREZ',
#     'position': 2.0,
#     'gapToPole': 0.03499999999999659,
#     'teammateGap': -0.05200000000000671,
#     'hasTeammateData': True},
#    {'round': 'French Grand Prix',
#     'driver': 'S PEREZ',
#     'position': 4.0,
#     'gapToPole': 0.4549999999999983,
#     'teammateGap': 0.4549999999999983,
#     'hasTeammateData': True},
#    {'round': 'Monaco Grand Prix',
#     'driver': 'S PEREZ',
#     'position': 9.0,
#     'gapToPole': 0.6730000000000018,
#     'teammateGap': 0.44300000000001205,
#     'hasTeammateData': True},
#    {'round': 'Portuguese Grand Prix',
#     'driver': 'S PEREZ',
#     'position': 4.0,
#     'gapToPole': 0.4969999999999999,
#     'teammateGap': 0.19499999999999318,
#     'hasTeammateData': True},
#    {'round': 'Spanish Grand Prix',
#     'driver': 'S PEREZ',
#     'position': 8.0,
#     'gapToPole': 0.9279999999999973,
#     'teammateGap': 0.8919999999999959,
#     'hasTeammateData': True}],
#   'avgQualifyingPosition': 6.428571428571429,
#   'avgGapToPole': 0.6659999999999988,
#   'avgTeammateGap': 0.523142857142856,
#   'dataCompleteness': 1.0},
#  {'year': 2021,
#   'driver': 'G RUSSELL',
#   'team': 'Williams',
#   'events': [{'round': 'Azerbaijan Grand Prix',
#     'driver': 'G RUSSELL',
#     'position': 15.0,
#     'gapToPole': 1.509999999999991,
#     'teammateGap': -0.4000000000000057,
#     'hasTeammateData': True},
#    {'round': 'Bahrain Grand Prix',
#     'driver': 'G RUSSELL',
#     'position': 15.0,
#     'gapToPole': 2.3190000000000026,
#     'teammateGap': -0.6200000000000045,
#     'hasTeammateData': True},
#    {'round': 'Emilia Romagna Grand Prix',
#     'driver': 'G RUSSELL',
#     'position': 12.0,
#     'gapToPole': 0.8499999999999943,
#     'teammateGap': -0.33200000000000784,
#     'hasTeammateData': True},
#    {'round': 'French Grand Prix',
#     'driver': 'G RUSSELL',
#     'position': 14.0,
#     'gapToPole': 2.075000000000003,
#     'teammateGap': -0.9969999999999999,
#     'hasTeammateData': True},
#    {'round': 'Monaco Grand Prix',
#     'driver': 'G RUSSELL',
#     'position': 15.0,
#     'gapToPole': 1.4839999999999947,
#     'teammateGap': -0.5360000000000014,
#     'hasTeammateData': True},
#    {'round': 'Portuguese Grand Prix',
#     'driver': 'G RUSSELL',
#     'position': 11.0,
#     'gapToPole': 0.7609999999999957,
#     'teammateGap': -1.176000000000002,
#     'hasTeammateData': True},
#    {'round': 'Spanish Grand Prix',
#     'driver': 'G RUSSELL',
#     'position': 15.0,
#     'gapToPole': 1.7039999999999935,
#     'teammateGap': -0.7740000000000009,
#     'hasTeammateData': True}],
#   'avgQualifyingPosition': 13.857142857142858,
#   'avgGapToPole': 1.5289999999999964,
#   'avgTeammateGap': -0.6907142857142888,
#   'dataCompleteness': 1.0},
#  {'year': 2021,
#   'driver': 'N LATIFI',
#   'team': 'Williams',
#   'events': [{'round': 'Azerbaijan Grand Prix',
#     'driver': 'N LATIFI',
#     'position': 16.0,
#     'gapToPole': 1.9099999999999966,
#     'teammateGap': 0.4000000000000057,
#     'hasTeammateData': True},
#    {'round': 'Bahrain Grand Prix',
#     'driver': 'N LATIFI',
#     'position': 17.0,
#     'gapToPole': 2.939000000000007,
#     'teammateGap': 0.6200000000000045,
#     'hasTeammateData': True},
#    {'round': 'Emilia Romagna Grand Prix',
#     'driver': 'N LATIFI',
#     'position': 14.0,
#     'gapToPole': 1.1820000000000022,
#     'teammateGap': 0.33200000000000784,
#     'hasTeammateData': True},
#    {'round': 'French Grand Prix',
#     'driver': 'N LATIFI',
#     'position': 16.0,
#     'gapToPole': 3.0720000000000027,
#     'teammateGap': 0.9969999999999999,
#     'hasTeammateData': True},
#    {'round': 'Monaco Grand Prix',
#     'driver': 'N LATIFI',
#     'position': 18.0,
#     'gapToPole': 2.019999999999996,
#     'teammateGap': 0.5360000000000014,
#     'hasTeammateData': True},
#    {'round': 'Portuguese Grand Prix',
#     'driver': 'N LATIFI',
#     'position': 18.0,
#     'gapToPole': 1.9369999999999976,
#     'teammateGap': 1.176000000000002,
#     'hasTeammateData': True},
#    {'round': 'Spanish Grand Prix',
#     'driver': 'N LATIFI',
#     'position': 19.0,
#     'gapToPole': 2.4779999999999944,
#     'teammateGap': 0.7740000000000009,
#     'hasTeammateData': True}],
#   'avgQualifyingPosition': 16.857142857142858,
#   'avgGapToPole': 2.2197142857142853,
#   'avgTeammateGap': 0.6907142857142888,
#   'dataCompleteness': 1.0},
#  {'year': 2021,
#   'driver': 'A GIOVINAZZI',
#   'team': 'Alfa Romeo Racing',
#   'events': [{'round': 'Bahrain Grand Prix',
#     'driver': 'A GIOVINAZZI',
#     'position': 12.0,
#     'gapToPole': 1.7109999999999985,
#     'teammateGap': -0.5300000000000011,
#     'hasTeammateData': True},
#    {'round': 'Emilia Romagna Grand Prix',
#     'driver': 'A GIOVINAZZI',
#     'position': 17.0,
#     'gapToPole': 1.7109999999999985,
#     'teammateGap': 0.14799999999999613,
#     'hasTeammateData': True},
#    {'round': 'French Grand Prix',
#     'driver': 'A GIOVINAZZI',
#     'position': 13.0,
#     'gapToPole': 1.8230000000000075,
#     'teammateGap': -1.5409999999999968,
#     'hasTeammateData': True},
#    {'round': 'Monaco Grand Prix',
#     'driver': 'A GIOVINAZZI',
#     'position': 10.0,
#     'gapToPole': 1.0630000000000024,
#     'teammateGap': -0.23299999999998988,
#     'hasTeammateData': True},
#    {'round': 'Portuguese Grand Prix',
#     'driver': 'A GIOVINAZZI',
#     'position': 12.0,
#     'gapToPole': 0.867999999999995,
#     'teammateGap': -0.5320000000000107,
#     'hasTeammateData': True},
#    {'round': 'Spanish Grand Prix',
#     'driver': 'A GIOVINAZZI',
#     'position': 14.0,
#     'gapToPole': 1.6149999999999949,
#     'teammateGap': -0.561000000000007,
#     'hasTeammateData': True}],
#   'avgQualifyingPosition': 13.0,
#   'avgGapToPole': 1.465166666666666,
#   'avgTeammateGap': -0.5415000000000015,
#   'dataCompleteness': 1.0},
#  {'year': 2021,
#   'driver': 'L STROLL',
#   'team': 'Aston Martin',
#   'events': [{'round': 'Bahrain Grand Prix',
#     'driver': 'L STROLL',
#     'position': 10.0,
#     'gapToPole': 1.6039999999999992,
#     'teammateGap': -1.4549999999999983,
#     'hasTeammateData': True},
#    {'round': 'Emilia Romagna Grand Prix',
#     'driver': 'L STROLL',
#     'position': 10.0,
#     'gapToPole': 0.7270000000000039,
#     'teammateGap': -0.2560000000000002,
#     'hasTeammateData': True},
#    {'round': 'French Grand Prix',
#     'driver': 'L STROLL',
#     'position': 19.0,
#     'gapToPole': 42.59400000000001,
#     'teammateGap': 40.81700000000001,
#     'hasTeammateData': True},
#    {'round': 'Monaco Grand Prix',
#     'driver': 'L STROLL',
#     'position': 13.0,
#     'gapToPole': 1.2539999999999907,
#     'teammateGap': 0.2909999999999968,
#     'hasTeammateData': True},
#    {'round': 'Portuguese Grand Prix',
#     'driver': 'L STROLL',
#     'position': 17.0,
#     'gapToPole': 1.5649999999999977,
#     'teammateGap': 0.9429999999999978,
#     'hasTeammateData': True},
#    {'round': 'Spanish Grand Prix',
#     'driver': 'L STROLL',
#     'position': 11.0,
#     'gapToPole': 1.233000000000004,
#     'teammateGap': -0.10499999999998977,
#     'hasTeammateData': True}],
#   'avgQualifyingPosition': 13.333333333333334,
#   'avgGapToPole': 8.162833333333333,
#   'avgTeammateGap': 6.705833333333335,
#   'dataCompleteness': 1.0}]
