# %%
import pandas as pd
import numpy as np
import panel as pn
import hvplot.pandas
import holoviews as hv
pn.extension('tabulator', 'plotly')
hv.extension('bokeh')

import importlib
import data_processing
importlib.reload(data_processing)

import plotly.graph_objects as go
from plotly.subplots import make_subplots

from typing import List, Dict
import logging

import os
from pathlib import Path
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='0907209f-e3a8-474d-9879-4fd015f14786'>
#   <div id="a60523d1-13bd-431c-8592-d769c46fd850" data-root-id="0907209f-e3a8-474d-9879-4fd015f14786" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"7d7298cc-b44c-46e4-ab31-d9f13ba52e52":{"version":"3.6.0","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"0907209f-e3a8-474d-9879-4fd015f14786"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"2d35274b-84b4-4052-a0ec-ad21142a311d","attributes":{"plot_id":"0907209f-e3a8-474d-9879-4fd015f14786","comm_id":"6a293d03d69644e0acd35dca1ab2d357","client_comm_id":"837cc8ccdaaa4d79afeb331f188787fe"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","def ...
#   var render_items = [{"docid":"7d7298cc-b44c-46e4-ab31-d9f13ba52e52","roots":{"0907209f-e3a8-474d-9879-4fd015f14786":"a60523d1-13bd-431c-8592-d769c46fd850"},"root_ids":["0907209f-e3a8-474d-9879-4fd015f14786"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined && ( root.Tabulator !== undefined) && ( root.Plotly !== undefined) && ( root.Tabulator !== undefined) && ( root.Plotly !== undefined) && ( root.Tabulator !== undefined) && ( root.Plotly !== undefined))
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 10
#       7 hv.extension('bokeh')
#       9 import importlib
# ---> 10 import data_processing
#      11 importlib.reload(data_processing)
#      13 import plotly.graph_objects as go
#
# ModuleNotFoundError: No module named 'data_processing'

# %%
def combine_csv_files(folder_path):
    """
    Read all CSV files from a folder and combine them into a single DataFrame.
    
    Parameters:
    folder_path (str): Path to the folder containing CSV files
    
    Returns:
    pandas.DataFrame: Combined DataFrame from all CSV files
    """
    path = Path(folder_path)
    all_dfs = []
    
    # Loop through all files in the folder
    for file in path.glob('*.csv'):
        try:
            df = pd.read_csv(file)
            # Append to the list
            all_dfs.append(df)
            
            print(f"Successfully read: {file.name}")
            
        except Exception as e:
            print(f"Error reading {file.name}: {str(e)}")
    
    # Combine all DataFrames
    if all_dfs:
        combined_df = pd.concat(all_dfs, ignore_index=True)
        print(f"\nTotal number of files combined: {len(all_dfs)}")
        print(f"Total rows in combined DataFrame: {len(combined_df)}")
        return combined_df
    else:
        print("No CSV files found in the specified folder!")
        return None

# %%
quali_data = combine_csv_files('data/results_data')
print(quali_data['Year'].unique())
quali_data.head()
# Out:
# Successfully read: qualifying_data_2019_results.csv
# Successfully read: qualifying_data_2022_results.csv
# Successfully read: qualifying_data_2021_results.csv
# Successfully read: qualifying_data_2018_results.csv
# Successfully read: qualifying_data_2020_results.csv
#
# Total number of files combined: 5
# Total rows in combined DataFrame: 1900
# [2019 2022 2021 2018 2020]
#    DriverNumber BroadcastName         TeamName  Position  \
# 0            44    L HAMILTON         Mercedes       1.0
# 1            77      V BOTTAS         Mercedes       2.0
# 2             5      S VETTEL          Ferrari       3.0
# 3            33  M VERSTAPPEN  Red Bull Racing       4.0
# 4            16     C LECLERC          Ferrari       5.0
#
#                        Q1                      Q2                      Q3  \
# 0  0 days 00:01:22.043000  0 days 00:01:21.014000  0 days 00:01:20.486000
# 1  0 days 00:01:22.367000  0 days 00:01:21.193000  0 days 00:01:20.598000
# 2  0 days 00:01:22.885000  0 days 00:01:21.912000  0 days 00:01:21.190000
# 3  0 days 00:01:22.876000  0 days 00:01:21.678000  0 days 00:01:21.320000
# 4  0 days 00:01:22.017000  0 days 00:01:21.739000  0 days 00:01:21.442000
#
#    Year              EventName  WetSession
# 0  2019  Australian Grand Prix       False
# 1  2019  Australian Grand Prix       False
# 2  2019  Australian Grand Prix       False
# 3  2019  Australian Grand Prix       False
# 4  2019  Australian Grand Prix       False

# %%
print(quali_data[['Q1', 'Q2', 'Q3']].dtypes)
# Out:
# Q1    object
# Q2    object
# Q3    object
# dtype: object

# %%
# Convert from string to Timedelta
quali_data['Q1'] = pd.to_timedelta(quali_data['Q1'])
quali_data['Q2'] = pd.to_timedelta(quali_data['Q2'])
quali_data['Q3'] = pd.to_timedelta(quali_data['Q3'])

# Now convert the Timedelta columns to total seconds
quali_data['Q1Seconds'] = quali_data['Q1'].apply(lambda x: x.total_seconds())
quali_data['Q2Seconds'] = quali_data['Q2'].apply(lambda x: x.total_seconds())
quali_data['Q3Seconds'] = quali_data['Q3'].apply(lambda x: x.total_seconds())

quali_data.head()
# Out:
#    DriverNumber BroadcastName         TeamName  Position  \
# 0            44    L HAMILTON         Mercedes       1.0
# 1            77      V BOTTAS         Mercedes       2.0
# 2             5      S VETTEL          Ferrari       3.0
# 3            33  M VERSTAPPEN  Red Bull Racing       4.0
# 4            16     C LECLERC          Ferrari       5.0
#
#                       Q1                     Q2                     Q3  Year  \
# 0 0 days 00:01:22.043000 0 days 00:01:21.014000 0 days 00:01:20.486000  2019
# 1 0 days 00:01:22.367000 0 days 00:01:21.193000 0 days 00:01:20.598000  2019
# 2 0 days 00:01:22.885000 0 days 00:01:21.912000 0 days 00:01:21.190000  2019
# 3 0 days 00:01:22.876000 0 days 00:01:21.678000 0 days 00:01:21.320000  2019
# 4 0 days 00:01:22.017000 0 days 00:01:21.739000 0 days 00:01:21.442000  2019
#
#                EventName  WetSession  Q1Seconds  Q2Seconds  Q3Seconds
# 0  Australian Grand Prix       False     82.043     81.014     80.486
# 1  Australian Grand Prix       False     82.367     81.193     80.598
# 2  Australian Grand Prix       False     82.885     81.912     81.190
# 3  Australian Grand Prix       False     82.876     81.678     81.320
# 4  Australian Grand Prix       False     82.017     81.739     81.442

# %%
quali_data.columns
# Out:
# Index(['DriverNumber', 'BroadcastName', 'TeamName', 'Position', 'Q1', 'Q2',
#        'Q3', 'Year', 'EventName', 'WetSession', 'Q1Seconds', 'Q2Seconds',
#        'Q3Seconds'],
#       dtype='object')

# %%
from typing import List, Dict
import logging


logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)


def process_qualifying_data(quali_data: pd.DataFrame) -> List[Dict]:
    """
    Process F1 qualifying data .
    
    """
    timeline_data = []
    
    # Verify cols
    required_columns = ['DriverNumber', 'BroadcastName', 'TeamName', 'Position', 'Q1', 'Q2',
       'Q3', 'Year', 'EventName', 'WetSession', 'Q1Seconds', 'Q2Seconds',
       'Q3Seconds']
    missing_columns = [col for col in required_columns if col not in quali_data.columns]
    if missing_columns:
        raise ValueError(f"Missing required columns: {missing_columns}")
    
    for year in quali_data['Year'].unique():
        year_data = quali_data[quali_data['Year'] == year]
        
        for event_name, event_data in year_data.groupby('EventName'):
            #logger.info(f"Processing {event_name} {year}")
            
            # Get pole position data (P1)
            pole_data = event_data[event_data['Position'] == 1].iloc[0]
            #pole_driver = pole_data['BroadcastName']
            pole_time = pole_data['Q3Seconds']
            
            team_groups = event_data.groupby('TeamName')
            
            for team, team_data in team_groups:
                drivers = team_data['BroadcastName'].unique()
                
                # Initialize gaps dict
                gaps = {driver: np.nan for driver in drivers}
                
                # Calculate teammate gaps only if 2 drivers
                if len(drivers) == 2:
                    driver1, driver2 = drivers
                    time1_data = team_data[team_data['BroadcastName'] == driver1].iloc[0]
                    time2_data = team_data[team_data['BroadcastName'] == driver2].iloc[0]
                    
                    time1 = None
                    if pd.notna(time1_data['Q3Seconds']):
                        time1 = time1_data['Q3Seconds']
                    elif pd.notna(time1_data['Q2Seconds']):
                        time1 = time1_data['Q2Seconds']
                    elif pd.notna(time1_data['Q1Seconds']):
                        time1 = time1_data['Q1Seconds']

                        
                    time2 = None  
                    if pd.notna(time2_data['Q3Seconds']):
                        time2 = time2_data['Q3Seconds']
                    elif pd.notna(time2_data['Q2Seconds']):
                        time2 = time2_data['Q2Seconds']
                    elif pd.notna(time2_data['Q1Seconds']):
                        time2 = time2_data['Q1Seconds']

                    if time1 is not None and time2 is not None:
                        gaps.update({                  #check 
                            driver1: time1 - time2,
                            driver2: time2 - time1
                        })
                else:
                    #pass
                    logger.info(f'Incomplete teammate data: {len(drivers)} driver(s) for {team} at {event_name} {year}')
                
                # Process each driver
                for driver in drivers:
                    driver_data = team_data[team_data['BroadcastName'] == driver].iloc[0]
                    best_time = None

                    if pd.notna(driver_data['Q3Seconds']):
                        best_time = driver_data['Q3Seconds']
                    elif pd.notna(driver_data['Q2Seconds']):
                        best_time = driver_data['Q2Seconds']
                    elif pd.notna(driver_data['Q1Seconds']):
                        best_time = driver_data['Q1Seconds']

                    qualifying_position = driver_data['Position'] if pd.notna(driver_data['Position']) else np.nan

                    
                    # Calculate gap to pole
                    if pd.isna(qualifying_position):
                        gap_to_pole = np.nan
                    elif qualifying_position == 1:
                        gap_to_pole = 0.0
                    elif best_time is None or pd.isna(pole_time):
                        gap_to_pole = np.nan
                    else:
                        gap_to_pole = best_time - pole_time 
                    
                    # Create event summary
                    event_summary = {
                        'round': event_name,
                        'position': qualifying_position,
                        'gapToPole': gap_to_pole,
                        'teammateGap': gaps[driver],
                        'hasTeammateData': not pd.isna(gaps[driver])
                    }
                    
                    # Find or create driver entry for this year
                    driver_entry = next(
                        (item for item in timeline_data if item['year'] == year and item['driver'] == driver),
                        None
                    )
                    
                    if driver_entry is None:
                        driver_entry = {
                            'year': year,
                            'driver': driver,
                            'team': team,
                            'events': [],
                            'positions': [],
                            'gapToPole_values': [],
                            'teammateGap_values': [],
                            'completeDataCount': 0,
                            'totalEvents': 0
                        }
                        timeline_data.append(driver_entry)
                    
                    driver_entry['events'].append(event_summary)
                    driver_entry['positions'].append(qualifying_position)
                    driver_entry['totalEvents'] += 1
                    
                    if gap_to_pole is not None and gap_to_pole != 'N/A':  #need to remove N/A options from this code 
                        driver_entry['gapToPole_values'].append(gap_to_pole)
                    if gaps[driver] is not None and gaps[driver] != 'N/A':
                        driver_entry['teammateGap_values'].append(gaps[driver])
                        driver_entry['completeDataCount'] += 1
    
    # Calculate final averages
    for entry in timeline_data:
        # Only include positions that are not NaN
        valid_positions = [pos for pos in entry['positions'] if not pd.isna(pos)]
        entry['avgQualifyingPosition'] = np.mean(valid_positions) if valid_positions else np.nan
    
         #Only include valid gap to pole times (exclude 'N/A' and NaN)
        valid_gaps_to_pole = [gap for gap in entry['gapToPole_values'] if not pd.isna(gap) and gap != 'N/A']
        entry['avgGapToPole'] = np.mean(valid_gaps_to_pole) if valid_gaps_to_pole else np.nan
    
        # Only include teammate gaps where there was actually a comparison
        valid_teammate_gaps = [gap for gap in entry['teammateGap_values'] if not pd.isna(gap) and gap != 'N/A']
        entry['avgTeammateGap'] = np.mean(valid_teammate_gaps) if valid_teammate_gaps else np.nan
    
        entry['dataCompleteness'] = entry['completeDataCount'] / entry['totalEvents'] if entry['totalEvents'] > 0 else 0
        
        del entry['positions']
        del entry['gapToPole_values']
        del entry['teammateGap_values']
        del entry['completeDataCount']
        del entry['totalEvents']
    
    return timeline_data

# %%
career_timeline_data = process_qualifying_data(quali_data)

# %%
career_timeline_data[:5]
# Out:
# [{'year': 2019,
#   'driver': 'A GIOVINAZZI',
#   'team': 'Alfa Romeo Racing',
#   'events': [{'round': 'Abu Dhabi Grand Prix',
#     'position': 17.0,
#     'gapToPole': 3.335000000000008,
#     'teammateGap': -0.26899999999999125,
#     'hasTeammateData': True},
#    {'round': 'Australian Grand Prix',
#     'position': 14.0,
#     'gapToPole': 2.2279999999999944,
#     'teammateGap': 0.4000000000000057,
#     'hasTeammateData': True},
#    {'round': 'Austrian Grand Prix',
#     'position': 8.0,
#     'gapToPole': 1.176000000000002,
#     'teammateGap': 0.01300000000000523,
#     'hasTeammateData': True},
#    {'round': 'Azerbaijan Grand Prix',
#     'position': 8.0,
#     'gapToPole': 1.929000000000002,
#     'teammateGap': nan,
#     'hasTeammateData': False},
#    {'round': 'Bahrain Grand Prix',
#     'position': 16.0,
#     'gapToPole': 2.1599999999999966,
#     'teammateGap': 1.0039999999999907,
#     'hasTeammateData': True},
#    {'round': 'Belgian Grand Prix',
#     'position': 15.0,
#     'gapToPole': 3.117999999999995,
#     'teammateGap': 1.0799999999999983,
#     'hasTeammateData': True},
#    {'round': 'Brazilian Grand Prix',
#     'position': 13.0,
#     'gapToPole': 1.4110000000000014,
#     'teammateGap': -0.06499999999999773,
#     'hasTeammateData': True},
#    {'round': 'British Grand Prix',
#     'position': 11.0,
#     'gapToPole': 1.426000000000002,
#     'teammateGap': -0.027000000000001023,
#     'hasTeammateData': True},
#    {'round': 'Canadian Grand Prix',
#     'position': 13.0,
#     'gapToPole': 1.8960000000000008,
#     'teammateGap': -0.0940000000000083,
#     'hasTeammateData': True},
#    {'round': 'Chinese Grand Prix',
#     'position': nan,
#     'gapToPole': nan,
#     'teammateGap': nan,
#     'hasTeammateData': False},
#    {'round': 'French Grand Prix',
#     'position': 10.0,
#     'gapToPole': 5.100999999999999,
#     'teammateGap': 2.8870000000000005,
#     'hasTeammateData': True},
#    {'round': 'German Grand Prix',
#     'position': 11.0,
#     'gapToPole': 1.0190000000000055,
#     'teammateGap': 0.24800000000000466,
#     'hasTeammateData': True},
#    {'round': 'Hungarian Grand Prix',
#     'position': 14.0,
#     'gapToPole': 2.2319999999999993,
#     'teammateGap': 0.7630000000000052,
#     'hasTeammateData': True},
#    {'round': 'Italian Grand Prix',
#     'position': 11.0,
#     'gapToPole': 1.2099999999999937,
#     'teammateGap': 0.001999999999995339,
#     'hasTeammateData': True},
#    {'round': 'Japanese Grand Prix',
#     'position': 11.0,
#     'gapToPole': 2.190000000000012,
#     'teammateGap': -0.1039999999999992,
#     'hasTeammateData': True},
#    {'round': 'Mexican Grand Prix',
#     'position': 15.0,
#     'gapToPole': 2.51100000000001,
#     'teammateGap': 0.3020000000000067,
#     'hasTeammateData': True},
#    {'round': 'Monaco Grand Prix',
#     'position': 15.0,
#     'gapToPole': 2.0190000000000055,
#     'teammateGap': 0.07000000000000739,
#     'hasTeammateData': True},
#    {'round': 'Russian Grand Prix',
#     'position': 13.0,
#     'gapToPole': 2.409000000000006,
#     'teammateGap': -0.8029999999999973,
#     'hasTeammateData': True},
#    {'round': 'Singapore Grand Prix',
#     'position': 11.0,
#     'gapToPole': 2.480000000000004,
#     'teammateGap': -0.16100000000000136,
#     'hasTeammateData': True},
#    {'round': 'Spanish Grand Prix',
#     'position': 18.0,
#     'gapToPole': 3.2579999999999956,
#     'teammateGap': 0.8760000000000048,
#     'hasTeammateData': True},
#    {'round': 'United States Grand Prix',
#     'position': 16.0,
#     'gapToPole': 2.1970000000000027,
#     'teammateGap': -0.14300000000000068,
#     'hasTeammateData': True}],
#   'avgQualifyingPosition': 13.0,
#   'avgGapToPole': 2.2652500000000018,
#   'avgTeammateGap': 0.31468421052631723,
#   'dataCompleteness': 1.0},
#  {'year': 2019,
#   'driver': 'K RAIKKONEN',
#   'team': 'Alfa Romeo Racing',
#   'events': [{'round': 'Abu Dhabi Grand Prix',
#     'position': 18.0,
#     'gapToPole': 3.603999999999999,
#     'teammateGap': 0.26899999999999125,
#     'hasTeammateData': True},
#    {'round': 'Australian Grand Prix',
#     'position': 9.0,
#     'gapToPole': 1.8279999999999887,
#     'teammateGap': -0.4000000000000057,
#     'hasTeammateData': True},
#    {'round': 'Austrian Grand Prix',
#     'position': 7.0,
#     'gapToPole': 1.1629999999999967,
#     'teammateGap': -0.01300000000000523,
#     'hasTeammateData': True},
#    {'round': 'Azerbaijan Grand Prix',
#     'position': 19.0,
#     'gapToPole': nan,
#     'teammateGap': nan,
#     'hasTeammateData': False},
#    {'round': 'Bahrain Grand Prix',
#     'position': 9.0,
#     'gapToPole': 1.156000000000006,
#     'teammateGap': -1.0039999999999907,
#     'hasTeammateData': True},
#    {'round': 'Belgian Grand Prix',
#     'position': 8.0,
#     'gapToPole': 2.0379999999999967,
#     'teammateGap': -1.0799999999999983,
#     'hasTeammateData': True},
#    {'round': 'Brazilian Grand Prix',
#     'position': 9.0,
#     'gapToPole': 1.475999999999999,
#     'teammateGap': 0.06499999999999773,
#     'hasTeammateData': True},
#    {'round': 'British Grand Prix',
#     'position': 12.0,
#     'gapToPole': 1.453000000000003,
#     'teammateGap': 0.027000000000001023,
#     'hasTeammateData': True},
#    {'round': 'Canadian Grand Prix',
#     'position': 17.0,
#     'gapToPole': 1.990000000000009,
#     'teammateGap': 0.0940000000000083,
#     'hasTeammateData': True},
#    {'round': 'Chinese Grand Prix',
#     'position': 13.0,
#     'gapToPole': 1.8719999999999999,
#     'teammateGap': nan,
#     'hasTeammateData': False},
#    {'round': 'French Grand Prix',
#     'position': 12.0,
#     'gapToPole': 2.2139999999999986,
#     'teammateGap': -2.8870000000000005,
#     'hasTeammateData': True},
#    {'round': 'German Grand Prix',
#     'position': 5.0,
#     'gapToPole': 0.7710000000000008,
#     'teammateGap': -0.24800000000000466,
#     'hasTeammateData': True},
#    {'round': 'Hungarian Grand Prix',
#     'position': 10.0,
#     'gapToPole': 1.468999999999994,
#     'teammateGap': -0.7630000000000052,
#     'hasTeammateData': True},
#    {'round': 'Italian Grand Prix',
#     'position': 10.0,
#     'gapToPole': 1.2079999999999984,
#     'teammateGap': -0.001999999999995339,
#     'hasTeammateData': True},
#    {'round': 'Japanese Grand Prix',
#     'position': 13.0,
#     'gapToPole': 2.294000000000011,
#     'teammateGap': 0.1039999999999992,
#     'hasTeammateData': True},
#    {'round': 'Mexican Grand Prix',
#     'position': 14.0,
#     'gapToPole': 2.209000000000003,
#     'teammateGap': -0.3020000000000067,
#     'hasTeammateData': True},
#    {'round': 'Monaco Grand Prix',
#     'position': 14.0,
#     'gapToPole': 1.948999999999998,
#     'teammateGap': -0.07000000000000739,
#     'hasTeammateData': True},
#    {'round': 'Russian Grand Prix',
#     'position': 16.0,
#     'gapToPole': 3.2120000000000033,
#     'teammateGap': 0.8029999999999973,
#     'hasTeammateData': True},
#    {'round': 'Singapore Grand Prix',
#     'position': 13.0,
#     'gapToPole': 2.6410000000000053,
#     'teammateGap': 0.16100000000000136,
#     'hasTeammateData': True},
#    {'round': 'Spanish Grand Prix',
#     'position': 14.0,
#     'gapToPole': 2.381999999999991,
#     'teammateGap': -0.8760000000000048,
#     'hasTeammateData': True},
#    {'round': 'United States Grand Prix',
#     'position': 17.0,
#     'gapToPole': 2.3400000000000034,
#     'teammateGap': 0.14300000000000068,
#     'hasTeammateData': True}],
#   'avgQualifyingPosition': 12.333333333333334,
#   'avgGapToPole': 1.9634500000000004,
#   'avgTeammateGap': -0.31468421052631723,
#   'dataCompleteness': 1.0},
#  {'year': 2019,
#   'driver': 'C LECLERC',
#   'team': 'Ferrari',
#   'events': [{'round': 'Abu Dhabi Grand Prix',
#     'position': 4.0,
#     'gapToPole': 0.4399999999999977,
#     'teammateGap': -0.12000000000000455,
#     'hasTeammateData': True},
#    {'round': 'Australian Grand Prix',
#     'position': 5.0,
#     'gapToPole': 0.9559999999999889,
#     'teammateGap': 0.25199999999999534,
#     'hasTeammateData': True},
#    {'round': 'Austrian Grand Prix',
#     'position': 1.0,
#     'gapToPole': 0.0,
#     'teammateGap': -0.6640000000000015,
#     'hasTeammateData': True},
#    {'round': 'Azerbaijan Grand Prix',
#     'position': 9.0,
#     'gapToPole': 1.5,
#     'teammateGap': 1.1980000000000075,
#     'hasTeammateData': True},
#    {'round': 'Bahrain Grand Prix',
#     'position': 1.0,
#     'gapToPole': 0.0,
#     'teammateGap': -0.29399999999999693,
#     'hasTeammateData': True},
#    {'round': 'Belgian Grand Prix',
#     'position': 1.0,
#     'gapToPole': 0.0,
#     'teammateGap': -0.7479999999999905,
#     'hasTeammateData': True},
#    {'round': 'Brazilian Grand Prix',
#     'position': 4.0,
#     'gapToPole': 0.21999999999999886,
#     'teammateGap': 0.0969999999999942,
#     'hasTeammateData': True},
#    {'round': 'British Grand Prix',
#     'position': 3.0,
#     'gapToPole': 0.07899999999999352,
#     'teammateGap': -0.6150000000000091,
#     'hasTeammateData': True},
#    {'round': 'Canadian Grand Prix',
#     'position': 3.0,
#     'gapToPole': 0.6800000000000068,
#     'teammateGap': 0.6800000000000068,
#     'hasTeammateData': True},
#    {'round': 'Chinese Grand Prix',
#     'position': 4.0,
#     'gapToPole': 0.31799999999999784,
#     'teammateGap': 0.016999999999995907,
#     'hasTeammateData': True},
#    {'round': 'French Grand Prix',
#     'position': 3.0,
#     'gapToPole': 0.6460000000000008,
#     'teammateGap': -0.8340000000000032,
#     'hasTeammateData': True},
#    {'round': 'German Grand Prix',
#     'position': 10.0,
#     'gapToPole': 0.5769999999999982,
#     'teammateGap': nan,
#     'hasTeammateData': False},
#    {'round': 'Hungarian Grand Prix',
#     'position': 4.0,
#     'gapToPole': 0.47100000000000364,
#     'teammateGap': -0.027999999999991587,
#     'hasTeammateData': True},
#    {'round': 'Italian Grand Prix',
#     'position': 1.0,
#     'gapToPole': 0.0,
#     'teammateGap': -0.14999999999999147,
#     'hasTeammateData': True},
#    {'round': 'Japanese Grand Prix',
#     'position': 2.0,
#     'gapToPole': 0.18900000000000716,
#     'teammateGap': 0.18900000000000716,
#     'hasTeammateData': True},
#    {'round': 'Mexican Grand Prix',
#     'position': 2.0,
#     'gapToPole': 0.26600000000000534,
#     'teammateGap': -0.1460000000000008,
#     'hasTeammateData': True},
#    {'round': 'Monaco Grand Prix',
#     'position': 16.0,
#     'gapToPole': 1.983000000000004,
#     'teammateGap': 1.2019999999999982,
#     'hasTeammateData': True},
#    {'round': 'Russian Grand Prix',
#     'position': 1.0,
#     'gapToPole': 0.0,
#     'teammateGap': -0.42499999999999716,
#     'hasTeammateData': True},
#    {'round': 'Singapore Grand Prix',
#     'position': 1.0,
#     'gapToPole': 0.0,
#     'teammateGap': -0.21999999999999886,
#     'hasTeammateData': True},
#    {'round': 'Spanish Grand Prix',
#     'position': 5.0,
#     'gapToPole': 1.181999999999988,
#     'teammateGap': 0.3159999999999883,
#     'hasTeammateData': True},
#    {'round': 'United States Grand Prix',
#     'position': 4.0,
#     'gapToPole': 0.10800000000000409,
#     'teammateGap': 0.09600000000000364,
#     'hasTeammateData': True}],
#   'avgQualifyingPosition': 4.0,
#   'avgGapToPole': 0.45785714285714263,
#   'avgTeammateGap': -0.009849999999999425,
#   'dataCompleteness': 1.0},
#  {'year': 2019,
#   'driver': 'S VETTEL',
#   'team': 'Ferrari',
#   'events': [{'round': 'Abu Dhabi Grand Prix',
#     'position': 5.0,
#     'gapToPole': 0.5600000000000023,
#     'teammateGap': 0.12000000000000455,
#     'hasTeammateData': True},
#    {'round': 'Australian Grand Prix',
#     'position': 3.0,
#     'gapToPole': 0.7039999999999935,
#     'teammateGap': -0.25199999999999534,
#     'hasTeammateData': True},
#    {'round': 'Austrian Grand Prix',
#     'position': 10.0,
#     'gapToPole': 0.6640000000000015,
#     'teammateGap': 0.6640000000000015,
#     'hasTeammateData': True},
#    {'round': 'Azerbaijan Grand Prix',
#     'position': 3.0,
#     'gapToPole': 0.3019999999999925,
#     'teammateGap': -1.1980000000000075,
#     'hasTeammateData': True},
#    {'round': 'Bahrain Grand Prix',
#     'position': 2.0,
#     'gapToPole': 0.29399999999999693,
#     'teammateGap': 0.29399999999999693,
#     'hasTeammateData': True},
#    {'round': 'Belgian Grand Prix',
#     'position': 2.0,
#     'gapToPole': 0.7479999999999905,
#     'teammateGap': 0.7479999999999905,
#     'hasTeammateData': True},
#    {'round': 'Brazilian Grand Prix',
#     'position': 2.0,
#     'gapToPole': 0.12300000000000466,
#     'teammateGap': -0.0969999999999942,
#     'hasTeammateData': True},
#    {'round': 'British Grand Prix',
#     'position': 6.0,
#     'gapToPole': 0.6940000000000026,
#     'teammateGap': 0.6150000000000091,
#     'hasTeammateData': True},
#    {'round': 'Canadian Grand Prix',
#     'position': 1.0,
#     'gapToPole': 0.0,
#     'teammateGap': -0.6800000000000068,
#     'hasTeammateData': True},
#    {'round': 'Chinese Grand Prix',
#     'position': 3.0,
#     'gapToPole': 0.30100000000000193,
#     'teammateGap': -0.016999999999995907,
#     'hasTeammateData': True},
#    {'round': 'French Grand Prix',
#     'position': 7.0,
#     'gapToPole': 1.480000000000004,
#     'teammateGap': 0.8340000000000032,
#     'hasTeammateData': True},
#    {'round': 'German Grand Prix',
#     'position': 20.0,
#     'gapToPole': nan,
#     'teammateGap': nan,
#     'hasTeammateData': False},
#    {'round': 'Hungarian Grand Prix',
#     'position': 5.0,
#     'gapToPole': 0.4989999999999952,
#     'teammateGap': 0.027999999999991587,
#     'hasTeammateData': True},
#    {'round': 'Italian Grand Prix',
#     'position': 4.0,
#     'gapToPole': 0.14999999999999147,
#     'teammateGap': 0.14999999999999147,
#     'hasTeammateData': True},
#    {'round': 'Japanese Grand Prix',
#     'position': 1.0,
#     'gapToPole': 0.0,
#     'teammateGap': -0.18900000000000716,
#     'hasTeammateData': True},
#    {'round': 'Mexican Grand Prix',
#     'position': 3.0,
#     'gapToPole': 0.41200000000000614,
#     'teammateGap': 0.1460000000000008,
#     'hasTeammateData': True},
#    {'round': 'Monaco Grand Prix',
#     'position': 4.0,
#     'gapToPole': 0.7810000000000059,
#     'teammateGap': -1.2019999999999982,
#     'hasTeammateData': True},
#    {'round': 'Russian Grand Prix',
#     'position': 3.0,
#     'gapToPole': 0.42499999999999716,
#     'teammateGap': 0.42499999999999716,
#     'hasTeammateData': True},
#    {'round': 'Singapore Grand Prix',
#     'position': 3.0,
#     'gapToPole': 0.21999999999999886,
#     'teammateGap': 0.21999999999999886,
#     'hasTeammateData': True},
#    {'round': 'Spanish Grand Prix',
#     'position': 3.0,
#     'gapToPole': 0.8659999999999997,
#     'teammateGap': -0.3159999999999883,
#     'hasTeammateData': True},
#    {'round': 'United States Grand Prix',
#     'position': 2.0,
#     'gapToPole': 0.012000000000000455,
#     'teammateGap': -0.09600000000000364,
#     'hasTeammateData': True}],
#   'avgQualifyingPosition': 4.380952380952381,
#   'avgGapToPole': 0.46174999999999927,
#   'avgTeammateGap': 0.009849999999999425,
#   'dataCompleteness': 1.0},
#  {'year': 2019,
#   'driver': 'K MAGNUSSEN',
#   'team': 'Haas F1 Team',
#   'events': [{'round': 'Abu Dhabi Grand Prix',
#     'position': 15.0,
#     'gapToPole': 2.4750000000000085,
#     'teammateGap': -0.796999999999997,
#     'hasTeammateData': True},
#    {'round': 'Australian Grand Prix',
#     'position': 7.0,
#     'gapToPole': 1.6129999999999995,
#     'teammateGap': 0.27300000000001035,
#     'hasTeammateData': True},
#    {'round': 'Austrian Grand Prix',
#     'position': 5.0,
#     'gapToPole': 1.0690000000000026,
#     'teammateGap': -0.41799999999999216,
#     'hasTeammateData': True},
#    {'round': 'Azerbaijan Grand Prix',
#     'position': 13.0,
#     'gapToPole': 2.2039999999999935,
#     'teammateGap': -0.7079999999999984,
#     'hasTeammateData': True},
#    {'round': 'Bahrain Grand Prix',
#     'position': 6.0,
#     'gapToPole': 0.8910000000000053,
#     'teammateGap': -0.25799999999999557,
#     'hasTeammateData': True},
#    {'round': 'Belgian Grand Prix',
#     'position': 10.0,
#     'gapToPole': 2.566999999999993,
#     'teammateGap': 0.2890000000000015,
#     'hasTeammateData': True},
#    {'round': 'Brazilian Grand Prix',
#     'position': 10.0,
#     'gapToPole': 1.5290000000000106,
#     'teammateGap': 0.18300000000000693,
#     'hasTeammateData': True},
#    {'round': 'British Grand Prix',
#     'position': 16.0,
#     'gapToPole': 1.5690000000000026,
#     'teammateGap': -0.09499999999999886,
#     'hasTeammateData': True},
#    {'round': 'Canadian Grand Prix',
#     'position': 10.0,
#     'gapToPole': 1.5460000000000065,
#     'teammateGap': -0.3229999999999933,
#     'hasTeammateData': True},
#    {'round': 'Chinese Grand Prix',
#     'position': 9.0,
#     'gapToPole': 1.6030000000000086,
#     'teammateGap': -0.006000000000000227,
#     'hasTeammateData': True},
#    {'round': 'French Grand Prix',
#     'position': 15.0,
#     'gapToPole': 3.120999999999995,
#     'teammateGap': -0.18600000000000705,
#     'hasTeammateData': True},
#    {'round': 'German Grand Prix',
#     'position': 12.0,
#     'gapToPole': 1.0220000000000056,
#     'teammateGap': -0.06199999999999761,
#     'hasTeammateData': True},
#    {'round': 'Hungarian Grand Prix',
#     'position': 15.0,
#     'gapToPole': 2.5090000000000003,
#     'teammateGap': 1.0679999999999978,
#     'hasTeammateData': True},
#    {'round': 'Italian Grand Prix',
#     'position': 12.0,
#     'gapToPole': 1.3079999999999927,
#     'teammateGap': -0.16900000000001114,
#     'hasTeammateData': True},
#    {'round': 'Japanese Grand Prix',
#     'position': 19.0,
#     'gapToPole': nan,
#     'teammateGap': nan,
#     'hasTeammateData': False},
#    {'round': 'Mexican Grand Prix',
#     'position': 17.0,
#     'gapToPole': 3.6780000000000115,
#     'teammateGap': -0.1629999999999967,
#     'hasTeammateData': True},
#    {'round': 'Monaco Grand Prix',
#     'position': 6.0,
#     'gapToPole': 0.9429999999999978,
#     'teammateGap': -0.9180000000000064,
#     'hasTeammateData': True},
#    {'round': 'Russian Grand Prix',
#     'position': 14.0,
#     'gapToPole': 2.4539999999999935,
#     'teammateGap': 0.5649999999999977,
#     'hasTeammateData': True},
#    {'round': 'Singapore Grand Prix',
#     'position': 14.0,
#     'gapToPole': 3.433000000000007,
#     'teammateGap': -0.6269999999999953,
#     'hasTeammateData': True},
#    {'round': 'Spanish Grand Prix',
#     'position': 8.0,
#     'gapToPole': 1.5159999999999911,
#     'teammateGap': 0.01099999999999568,
#     'hasTeammateData': True},
#    {'round': 'United States Grand Prix',
#     'position': 12.0,
#     'gapToPole': 1.9500000000000028,
#     'teammateGap': -0.17900000000000205,
#     'hasTeammateData': True}],
#   'avgQualifyingPosition': 11.666666666666666,
#   'avgGapToPole': 1.9500000000000015,
#   'avgTeammateGap': -0.12599999999999908,
#   'dataCompleteness': 1.0}]

# %%
year_list = []
for dict in career_timeline_data:
    year_list.append(dict['year'])
set(year_list)
# Out:
# {2018, 2019, 2020, 2021, 2022}

# %%
len(set(entry['driver'] for entry in career_timeline_data))
# Out:
# 33

# %% [markdown]
# ### Dashboard

# %%
def create_driver_timeline(timeline_data):
    df = pd.DataFrame(timeline_data)
    all_drivers = sorted(df['driver'].unique().tolist())
    driver_selector = pn.widgets.Select(name='Driver', options=all_drivers, width=200)    #driver dropdown menu 
    
    def create_year_panel(year_data):
        events_df = pd.DataFrame(year_data['events'])
        valid_pos_df = events_df.dropna(subset=['position'])
        valid_pos_df['short_round'] = valid_pos_df['round'].str.replace(' Grand Prix', '')        
        
        scatter_plot = valid_pos_df.hvplot.scatter( #quali plot 
            'round', 'position',
            title="Qualifying Performance",
            width=1000, 
            height=400,
            ylim=(20, 1),
            size=12,
            hover_cols=['round', 'gapToPole', 'teammateGap'] #tooltip
        ).opts(
            padding=0.1,
            show_grid=True,
            fontsize={'labels': 8, 'xticks': 8, 'yticks': 10, 'title': 14},
            xrotation=45,
            margin=(50,50,100,50),
            tools=['hover', 'box_zoom', 'reset'] #'pan'?
        )
        #performance metrics
        metrics = pn.Row(
            pn.pane.Markdown(f"Year: {year_data['year']}"),
            pn.pane.Markdown(f"Team: {year_data['team']}"),
            pn.pane.Markdown(f"Avg Qualifying: {year_data['avgQualifyingPosition']:.2f}"),
            pn.pane.Markdown(f"Avg Gap to Pole: {year_data['avgGapToPole']:.3f}s"),
            pn.pane.Markdown(f"vs Teammate: {year_data['avgTeammateGap']:.3f}s")#,
            #pn.pane.Markdown(f"Data Completeness: {year_data['dataCompleteness']*100:.0f}%")
        )        
        
        return pn.Column(
            metrics,
            pn.pane.HoloViews(scatter_plot, sizing_mode='stretch_width'), #put metrics in row 
            sizing_mode='stretch_width'
        )

    @pn.depends(driver_selector.param.value #change based on driver selection 
    def create_timeline(driver):
        if not driver:
            return pn.Column(pn.pane.Markdown("Please select a driver"))
            
        driver_data = df[df['driver'] == driver].sort_values('year') #filter driver data
        timeline_panels = [create_year_panel(year_data) for _, year_data in driver_data.iterrows()] #create panels
        
        return pn.Column(
            pn.pane.Markdown(f"# {driver}'s Qualifying Timeline"),
            *timeline_panels, #unpacked 
            sizing_mode='stretch_width' #fit width 
        )    
    
    return pn.Column(
        pn.Row(driver_selector),
        pn.layout.Divider(),
        create_timeline,
        sizing_mode='stretch_width' #final layout wiht dropdown, divider, generate timeline 
    )

# %%
dashboard = create_driver_timeline(career_timeline_data)
# Out:
# /var/folders/y0/lmjvhh9x73bbfknbrk6scl4h0000gn/T/ipykernel_61202/2969340996.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_pos_df['short_round'] = valid_pos_df['round'].str.replace(' Grand Prix', '')

# %%
dashboard.show()
# Out:
# INFO:bokeh.server.server:Starting Bokeh server version 3.6.0 (running on Tornado 6.4.1)
# INFO:bokeh.server.tornado:User authentication hooks NOT provided (default user enabled)
# Launching server at http://localhost:61572
# INFO:tornado.access:200 GET / (::1) 223.39ms
# INFO:tornado.access:200 GET / (::1) 223.39ms
# INFO:tornado.access:200 GET /static/extensions/panel/bundled/plotlyplot/mapbox-gl-js/v3.0.1/mapbox-gl.css?v=1.5.2 (::1) 25.62ms
# INFO:tornado.access:200 GET /static/extensions/panel/bundled/plotlyplot/mapbox-gl-js/v3.0.1/mapbox-gl.css?v=1.5.2 (::1) 25.62ms
# INFO:tornado.access:200 GET /static/extensions/panel/bundled/reactiveesm/es-module-shims@%5E1.10.0/dist/es-module-shims.min.js (::1) 29.93ms
# INFO:tornado.access:200 GET /static/extensions/panel/bundled/reactiveesm/es-module-shims@%5E1.10.0/dist/es-module-shims.min.js (::1) 29.93ms
# INFO:tornado.access:200 GET /static/extensions/panel/bundled/jquery/jquery.slim.min.js (::1) 30.75ms
# INFO:tornado.access:200 GET /static/extensions/panel/bundled/jquery/jquery.slim.min.js (::1) 30.75ms
# INFO:tornado.access:200 GET /static/extensions/panel/bundled/datatabulator/tabulator-tables@6.2.1/dist/js/tabulator.min.js (::1) 38.95ms
# INFO:tornado.access:200 GET /static/extensions/panel/bundled/datatabulator/tabulator-tables@6.2.1/dist/js/tabulator.min.js (::1) 38.95ms
# INFO:tornado.access:200 GET /static/extensions/panel/bundled/datatabulator/tabulator-tables@6.2.1/dist/css/tabulator_simple.min.css?v=1.5.2 (::1) 13.91ms
# INFO:tornado.access:200 GET /static/extensions/panel/bundled/datatabulator/tabulator-tables@6.2.1/dist/css/tabulator_simple.min.css?v=1.5.2 (::1) 13.91ms
# INFO:tornado.access:200 GET /static/extensions/panel/bundled/datatabulator/luxon/build/global/luxon.min.js (::1) 8.80ms
# INFO:tornado.access:200 GET /static/extensions/panel/bundled/datatabulator/luxon/build/global/luxon.min.js (::1) 8.80ms
# INFO:tornado.access:200 GET /static/js/bokeh-gl.min.js?v=674dcea77483f8996a069d63e07657e6f744a37d10997e93f172179a5ba5d1c9d7621815eeb5bd909aa463644476c1382f6254b9f387002e9ccfa6e640ddf0bb (::1) 18.50ms
# INFO:tornado.access:200 GET /static/js/bokeh-gl.min.js?v=674dcea77483f8996a069d63e07657e6f744a37d10997e93f172179a5ba5d1c9d7621815eeb5bd909aa463644476c1382f6254b9f387002e9ccfa6e640ddf0bb (::1) 18.50ms
# INFO:tornado.access:200 GET /static/js/bokeh-widgets.min.js?v=fbdc924ac6c91fc9327f170e493da343090822b9951b2eaec18e0a2a4811fc5960912ede4066d269976232f7acfcc5b21a36b40b14d357c113cad957eb9cb3a7 (::1) 25.36ms
# INFO:tornado.access:200 GET /static/js/bokeh-widgets.min.js?v=fbdc924ac6c91fc9327f170e493da343090822b9951b2eaec18e0a2a4811fc5960912ede4066d269976232f7acfcc5b21a36b40b14d357c113cad957eb9cb3a7 (::1) 25.36ms
# INFO:tornado.access:200 GET /static/js/bokeh-tables.min.js?v=676e60ffbaef467a0f8e2321dd663a259b7d45834cb8f2b27597650b8bb80ec0288acae28a58fffa5d504d54d3a99ae27a03b20ad03eec4aa18bf8c8cfb4ec4b (::1) 8.94ms
# INFO:tornado.access:200 GET /static/js/bokeh-tables.min.js?v=676e60ffbaef467a0f8e2321dd663a259b7d45834cb8f2b27597650b8bb80ec0288acae28a58fffa5d504d54d3a99ae27a03b20ad03eec4aa18bf8c8cfb4ec4b (::1) 8.94ms
# INFO:tornado.access:200 GET /static/extensions/panel/panel.min.js?v=035542f344c4003c60b082b33b07ef53ef25b5bdc5d9acb7ae9fd03f4c6edba4 (::1) 2.64ms
# INFO:tornado.access:200 GET /static/extensions/panel/panel.min.js?v=035542f344c4003c60b082b33b07ef53ef25b5bdc5d9acb7ae9fd03f4c6edba4 (::1) 2.64ms
# INFO:tornado.access:200 GET /static/js/bokeh.min.js?v=de958ab1870cd066dba119c34f40c5e1ca4af9c0d31988f4020e6c49a056838b8968f69e29f359fb6dae256aed026344b1797302c230126c662521f0895deb32 (::1) 54.66ms
# INFO:tornado.access:200 GET /static/js/bokeh.min.js?v=de958ab1870cd066dba119c34f40c5e1ca4af9c0d31988f4020e6c49a056838b8968f69e29f359fb6dae256aed026344b1797302c230126c662521f0895deb32 (::1) 54.66ms
# INFO:tornado.access:200 GET /static/extensions/panel/bundled/plotlyplot/plotly-2.31.1.min.js (::1) 125.62ms
# INFO:tornado.access:200 GET /static/extensions/panel/bundled/plotlyplot/plotly-2.31.1.min.js (::1) 125.62ms
# INFO:tornado.access:101 GET /ws (::1) 0.60ms
# INFO:tornado.access:101 GET /ws (::1) 0.60ms
# INFO:bokeh.server.views.ws:WebSocket connection opened
# INFO:bokeh.server.views.ws:ServerConnection created
# INFO:tornado.access:200 GET /static/extensions/panel/images/favicon.ico (::1) 1.44ms
# INFO:tornado.access:200 GET /static/extensions/panel/images/favicon.ico (::1) 1.44ms
# INFO:tornado.access:200 GET /static/extensions/panel/css/loading.css?v=1.5.2 (::1) 1.45ms
# INFO:tornado.access:200 GET /static/extensions/panel/css/loading.css?v=1.5.2 (::1) 1.45ms
# INFO:tornado.access:200 GET /static/extensions/panel/css/listpanel.css?v=1.5.2 (::1) 1.96ms
# INFO:tornado.access:200 GET /static/extensions/panel/css/listpanel.css?v=1.5.2 (::1) 1.96ms
# INFO:tornado.access:200 GET /static/extensions/panel/css/markdown.css?v=1.5.2 (::1) 2.03ms
# INFO:tornado.access:200 GET /static/extensions/panel/css/markdown.css?v=1.5.2 (::1) 2.03ms
# INFO:tornado.access:200 GET /static/extensions/panel/bundled/theme/default.css?v=1.5.2 (::1) 4.11ms
# INFO:tornado.access:200 GET /static/extensions/panel/bundled/theme/default.css?v=1.5.2 (::1) 4.11ms
# INFO:tornado.access:200 GET /static/extensions/panel/bundled/theme/native.css?v=1.5.2 (::1) 6.15ms
# INFO:tornado.access:200 GET /static/extensions/panel/bundled/theme/native.css?v=1.5.2 (::1) 6.15ms
# INFO:tornado.access:200 GET /static/extensions/panel/css/select.css?v=1.5.2 (::1) 8.70ms
# INFO:tornado.access:200 GET /static/extensions/panel/css/select.css?v=1.5.2 (::1) 8.70ms
# INFO:tornado.access:200 GET /static/extensions/panel/css/divider.css?v=1.5.2 (::1) 13.26ms
# INFO:tornado.access:200 GET /static/extensions/panel/css/divider.css?v=1.5.2 (::1) 13.26ms
