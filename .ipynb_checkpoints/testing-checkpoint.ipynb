# %%
import fastf1
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Enable FastF1 cache
fastf1.Cache.enable_cache('f1_cache')

# Load the session
session = fastf1.get_session(2018, 'Azerbaijan', 'Q')
session.load()

# Get weather data
weather_data = session.weather_data

# Display basic info about the weather data
print("Weather Data Columns:", weather_data.columns)
print("\nFirst few rows of weather data:")
print(weather_data.head())
# Out:
# core           INFO 	Loading data for Azerbaijan Grand Prix - Qualifying [v3.4.4]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['5', '44', '77', '3', '33', '7', '31', '11', '27', '55', '18', '35', '14', '16', '20', '2', '10', '9', '28', '8']
# ...

# %%
weather_data[weather_data['Rainfall'] > 0]
# Out:
#                      Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 8  0 days 00:08:41.783000     22.3      46.8    1015.2      True       26.9
# 9  0 days 00:09:43.103000     22.4      46.6    1015.2      True       26.9
# 10 0 days 00:10:34.403000     22.4      46.8    1015.3      True       26.9
# 11 0 days 00:11:34.302000     22.4      46.8    1015.2      True       27.0
# 12 0 days 00:12:34.302000     22.4      46.6    1015.2      True       27.0
#
#     WindDirection  WindSpeed
# 8             241        1.9
# 9             244        1.9
# 10            204        1.6
# 11            261        0.6
# 12            266        1.9

# %%
quali_2018 = pd.read_csv('data/original_data/updated_years/qualifying_data_2018.csv')
quali_2018.head()
# Out:
#                      Time      Driver  DriverNumber                 LapTime  \
# 0  0 days 00:08:49.865000  L HAMILTON            44  0 days 00:01:47.929000
# 1  0 days 00:10:13.667000  L HAMILTON            44  0 days 00:01:23.802000
# 2  0 days 00:12:06.203000  L HAMILTON            44  0 days 00:01:52.536000
# 3  0 days 00:13:29.466000  L HAMILTON            44  0 days 00:01:23.263000
# 4  0 days 00:15:28.217000  L HAMILTON            44  0 days 00:01:58.751000
#
#    LapNumber  Stint              PitOutTime PitInTime             Sector1Time  \
# 0        1.0    1.0  0 days 00:07:06.138000       NaN  0 days 00:00:42.222000
# 1        2.0    1.0                     NaN       NaN  0 days 00:00:27.667000
# 2        3.0    1.0                     NaN       NaN  0 days 00:00:42.357000
# 3        4.0    1.0                     NaN       NaN  0 days 00:00:27.410000
# 4        5.0    1.0                     NaN       NaN  0 days 00:00:35.598000
#
# ...

# %%
quali_2018[
    (quali_2018['Team'] == 'Red Bull Racing') & 
    (quali_2018['EventName'] == 'German Grand Prix') &
    (quali_2018['Driver'] == 'D RICCIARDO') #&
   # (quali_2018['Deleted'] == False ) #&
    #(quali_2018['TrackStatus'] == 1) &
    #(quali_2018['IsAccurate'] == True)
]
# Out:
#                         Time       Driver  DriverNumber  \
# 3244  0 days 00:13:46.591000  D RICCIARDO             3
# 3245  0 days 00:15:00.142000  D RICCIARDO             3
# 3246  0 days 00:17:00.227000  D RICCIARDO             3
# 3247  0 days 00:18:36.699000  D RICCIARDO             3
# 3248  0 days 00:19:50.017000  D RICCIARDO             3
# 3249  0 days 00:21:32.059000  D RICCIARDO             3
#
#                      LapTime  LapNumber  Stint              PitOutTime  \
# 3244                     NaN        1.0    1.0  0 days 00:12:10.560000
# 3245  0 days 00:01:13.551000        2.0    1.0                     NaN
# 3246  0 days 00:02:00.085000        3.0    1.0                     NaN
# 3247  0 days 00:01:36.472000        4.0    1.0                     NaN
# 3248  0 days 00:01:13.318000        5.0    1.0                     NaN
# 3249  0 days 00:01:42.042000        6.0    1.0                     NaN
#
# ...
